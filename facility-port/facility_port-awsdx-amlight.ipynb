# %% [markdown]
# # Create a FABRIC Facility Port
#
# This notebook shows how to use create an facility port to connect your FABRIC experiment to an external facility.

# %% [markdown]
# ## Import the FABlib Library

# %%
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

fablib = fablib_manager()
                     
fablib.show_config();
# Out:
# <style type="text/css">
# #T_b20a6 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_b20a6 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_b20a6 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_b20a6_row0_col0, #T_b20a6_row0_col1, #T_b20a6_row1_col0, #T_b20a6_row1_col1, #T_b20a6_row2_col0, #T_b20a6_row2_col1, #T_b20a6_row3_col0, #T_b20a6_row3_col1, #T_b20a6_row4_col0, #T_b20a6_row4_col1, #T_b20a6_row5_col0, #T_b20a6_row5_col1, #T_b20a6_row6_col0, #T_b20a6_row6_col1, #T_b20a6_row7_col0, #T_b20a6_row7_col1, #T_b20a6_row8_col0, #T_b20a6_row8_col1, #T_b20a6_row9_col0, #T_b20a6_row9_col1, #T_b20a6_row10_col0, #T_b20a6_row10_col1, #T_b20a6_row11_col0, #T_b20a6_row11_col1, #T_b20a6_row12_col0, #T_b20a6_row12_col1, #T_b20a6_row13_col0, #T_b20a6_row13_col1, #T_b20a6_row14_col0, #T_b20a6_row14_col1, #T_b20a6_row15_col0, #T_b20a6_row15_col1, #T_b20a6_row16_col0, #T_b20a6_row16_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_b20a6">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b20a6_row0_col0" class="data row0 col0" >Credential Manager</td>
#       <td id="T_b20a6_row0_col1" class="data row0 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_b20a6_row1_col0" class="data row1 col0" >Orchestrator</td>
#       <td id="T_b20a6_row1_col1" class="data row1 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_b20a6_row2_col0" class="data row2 col0" >Project ID</td>
#       <td id="T_b20a6_row2_col1" class="data row2 col1" >990d8a8b-7e50-4d13-a3be-0f133ffa8653</td>
#     </tr>
#     <tr>
#       <td id="T_b20a6_row3_col0" class="data row3 col0" >Token File</td>
#       <td id="T_b20a6_row3_col1" class="data row3 col1" >/home/fabric/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_b20a6_row4_col0" class="data row4 col0" >Bastion Host</td>
#       <td id="T_b20a6_row4_col1" class="data row4 col1" >bastion-renc-1.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_b20a6_row5_col0" class="data row5 col0" >Bastion Username</td>
#       <td id="T_b20a6_row5_col1" class="data row5 col1" >mcevik_0000100641</td>
#     </tr>
#     <tr>
#       <td id="T_b20a6_row6_col0" class="data row6 col0" >Bastion Private Key File</td>
#       <td id="T_b20a6_row6_col1" class="data row6 col1" >/home/fabric/work/fabric_config/mcevik_fabric_bastion_1</td>
#     </tr>
#     <tr>
#       <td id="T_b20a6_row7_col0" class="data row7 col0" >Slice Private Key File</td>
#       <td id="T_b20a6_row7_col1" class="data row7 col1" >/home/fabric/work/fabric_config/mcevik_fabric_sliver_1</td>
#     </tr>
#     <tr>
#       <td id="T_b20a6_row8_col0" class="data row8 col0" >Slice Public Key File</td>
#       <td id="T_b20a6_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/mcevik_fabric_sliver_1.pub</td>
#     </tr>
#     <tr>
#       <td id="T_b20a6_row9_col0" class="data row9 col0" >Log File</td>
#       <td id="T_b20a6_row9_col1" class="data row9 col1" >/tmp/fablib/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_b20a6_row10_col0" class="data row10 col0" >Log Level</td>
#       <td id="T_b20a6_row10_col1" class="data row10 col1" >INFO</td>
#     </tr>
#     <tr>
#       <td id="T_b20a6_row11_col0" class="data row11 col0" >Sites to avoid</td>
#       <td id="T_b20a6_row11_col1" class="data row11 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_b20a6_row12_col0" class="data row12 col0" >SSH Command Line</td>
#       <td id="T_b20a6_row12_col1" class="data row12 col1" >ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}</td>
#     </tr>
#     <tr>
#       <td id="T_b20a6_row13_col0" class="data row13 col0" >Version</td>
#       <td id="T_b20a6_row13_col1" class="data row13 col1" >1.7.3</td>
#     </tr>
#     <tr>
#       <td id="T_b20a6_row14_col0" class="data row14 col0" >Data directory</td>
#       <td id="T_b20a6_row14_col1" class="data row14 col1" >/tmp/fablib</td>
#     </tr>
#     <tr>
#       <td id="T_b20a6_row15_col0" class="data row15 col0" >Core API</td>
#       <td id="T_b20a6_row15_col1" class="data row15 col1" >uis.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_b20a6_row16_col0" class="data row16 col0" >Bastion SSH Config File</td>
#       <td id="T_b20a6_row16_col1" class="data row16 col1" >/home/fabric/work/fabric_config/ssh_config</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Create the Experiment Slice
#
# The following creates a single node with basic compute capabilities. You build a slice by creating a new slice and adding resources to the slice. After you build the slice, you must submit a request for the slice to be instantiated.
#
# By default, the submit function will block until the node is ready and will display the progress of your slice being built.

# %%
slice_name = "Slice-AWSDX"

facility_port_site='FIU'

# %% [markdown]
# ### Facility port info

# %% [markdown]
# #### Find the facility ports on the site
# List the facility ports
# - Facility Port Name
# - Available VLAN range
# - Currently allocated VLAN range

# %%
cell_output = 'pandas' # 'json'
output_list = fablib.list_facility_ports(filter_function=lambda x: x['site_name'] == facility_port_site, output=cell_output)
# Out:
# <style type="text/css">
# #T_edcce caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_edcce th {
#   text-align: left;
# }
# #T_edcce tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_edcce tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_edcce .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_edcce_row0_col0, #T_edcce_row0_col1, #T_edcce_row0_col2, #T_edcce_row0_col3, #T_edcce_row0_col4, #T_edcce_row0_col5, #T_edcce_row0_col6, #T_edcce_row0_col7, #T_edcce_row1_col0, #T_edcce_row1_col1, #T_edcce_row1_col2, #T_edcce_row1_col3, #T_edcce_row1_col4, #T_edcce_row1_col5, #T_edcce_row1_col6, #T_edcce_row1_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_edcce">
#   <caption>Facility Ports</caption>
#   <thead>
#     <tr>
#       <th id="T_edcce_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_edcce_level0_col1" class="col_heading level0 col1" >Site</th>
#       <th id="T_edcce_level0_col2" class="col_heading level0 col2" >Interface Name</th>
#       <th id="T_edcce_level0_col3" class="col_heading level0 col3" >VLAN Range</th>
#       <th id="T_edcce_level0_col4" class="col_heading level0 col4" >Allocated VLAN Range</th>
#       <th id="T_edcce_level0_col5" class="col_heading level0 col5" >Local Name</th>
#       <th id="T_edcce_level0_col6" class="col_heading level0 col6" >Device Name</th>
#       <th id="T_edcce_level0_col7" class="col_heading level0 col7" >Region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_edcce_row0_col0" class="data row0 col0" >AmLight-EXP-Layer2-FIU</td>
#       <td id="T_edcce_row0_col1" class="data row0 col1" >FIU</td>
#       <td id="T_edcce_row0_col2" class="data row0 col2" >port+fiu-data-sw:HundredGigE0/0/0/23:facility+AmLight-EXP-Layer2-FIU-int</td>
#       <td id="T_edcce_row0_col3" class="data row0 col3" >['4000-4019']</td>
#       <td id="T_edcce_row0_col4" class="data row0 col4" >N/A</td>
#       <td id="T_edcce_row0_col5" class="data row0 col5" >N/A</td>
#       <td id="T_edcce_row0_col6" class="data row0 col6" >N/A</td>
#       <td id="T_edcce_row0_col7" class="data row0 col7" >N/A</td>
#     </tr>
#     <tr>
#       <td id="T_edcce_row1_col0" class="data row1 col0" >AmLight-Layer3-FIU</td>
#       <td id="T_edcce_row1_col1" class="data row1 col1" >FIU</td>
#       <td id="T_edcce_row1_col2" class="data row1 col2" >port+fiu-data-sw:HundredGigE0/0/0/23:facility+AmLight-Layer3-FIU-int</td>
#       <td id="T_edcce_row1_col3" class="data row1 col3" >['3001-3008']</td>
#       <td id="T_edcce_row1_col4" class="data row1 col4" >N/A</td>
#       <td id="T_edcce_row1_col5" class="data row1 col5" >N/A</td>
#       <td id="T_edcce_row1_col6" class="data row1 col6" >N/A</td>
#       <td id="T_edcce_row1_col7" class="data row1 col7" >N/A</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Select the Facility Port on the site
#
# Set the facility port name and select the VLAN to use

# %%
facility_port_name = 'AmLight-EXP-Layer2-FIU' # VLAN Range: 4000-4019
#facility_port_name ='AmLight-Layer3-FIU'     # VLAN Range: 3001-3008

facility_port_vlan='4015'

# %% [markdown]
# ### Create Slice

# %% [markdown]
# Create new_slice and add node(s) to the FABRIC topology

# %%
slice = fablib.new_slice(name=slice_name)

# Example: One VM on FABRIC-STAR with a NIC - sharedNIC (basic) or dedicated smartNIC (ConnectX_6)
node = slice.add_node(name=f"Node1", site='STAR')

#node_iface = node.add_component(model='NIC_ConnectX_6', name="nic1").get_interfaces()[0]
node_iface = node.add_component(model='NIC_Basic', name="nic1").get_interfaces()[0]

# %% [markdown]
# Add facility port to the network service configuration along with the node interface(s)

# %%
facility_port = slice.add_facility_port(name=facility_port_name, site=facility_port_site, vlan=facility_port_vlan)
facility_port_interface =facility_port.get_interfaces()[0]

#net = slice.add_l2network(name=f'net_facility_port', interfaces=[node_iface,facility_port_interface])
net = slice.add_l2network(name=f'net_facility_port', interfaces=[])
net.add_interface(node_iface)
net.add_interface(facility_port_interface)

# %%
print(f"facility_port.get_site(): {facility_port.get_site()}")
print(f"facility_port.get_fim_interface(): {facility_port.get_fim_interface()}")
# Out:
# facility_port.get_site(): FIU
# facility_port.get_fim_interface(): {'node_id': 'e1887f1e-a860-4b6f-a80b-dfe3a1970a85', 'name': 'AmLight-EXP-Layer2-FIU', 'site': 'FIU', 'type': 'Facility'}

# %% [markdown]
# Submit slice request to create

# %%
slice.submit();
# Out:
# Retry: 9, Time: 269 sec
# <style type="text/css">
# #T_b5688 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_b5688 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_b5688 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_b5688_row0_col0, #T_b5688_row0_col1, #T_b5688_row1_col0, #T_b5688_row1_col1, #T_b5688_row2_col0, #T_b5688_row2_col1, #T_b5688_row3_col0, #T_b5688_row3_col1, #T_b5688_row4_col0, #T_b5688_row4_col1, #T_b5688_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_b5688_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_b5688">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b5688_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_b5688_row0_col1" class="data row0 col1" >ac215229-873c-4107-b4d3-96ed9a90a107</td>
#     </tr>
#     <tr>
#       <td id="T_b5688_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_b5688_row1_col1" class="data row1 col1" >Slice-AWSDX</td>
#     </tr>
#     <tr>
#       <td id="T_b5688_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_b5688_row2_col1" class="data row2 col1" >2024-10-04 17:28:55 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_b5688_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_b5688_row3_col1" class="data row3 col1" >2024-10-03 17:28:55 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_b5688_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_b5688_row4_col1" class="data row4 col1" >990d8a8b-7e50-4d13-a3be-0f133ffa8653</td>
#     </tr>
#     <tr>
#       <td id="T_b5688_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_b5688_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_e6a07 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_e6a07 th {
#   text-align: left;
# }
# #T_e6a07 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_e6a07 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_e6a07 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_e6a07_row0_col0, #T_e6a07_row0_col1, #T_e6a07_row0_col2, #T_e6a07_row0_col3, #T_e6a07_row0_col4, #T_e6a07_row0_col5, #T_e6a07_row0_col6, #T_e6a07_row0_col7, #T_e6a07_row0_col8, #T_e6a07_row0_col9, #T_e6a07_row0_col10, #T_e6a07_row0_col13, #T_e6a07_row0_col14, #T_e6a07_row0_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_e6a07_row0_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_e6a07_row0_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_e6a07">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_e6a07_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_e6a07_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_e6a07_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_e6a07_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_e6a07_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_e6a07_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_e6a07_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_e6a07_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_e6a07_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_e6a07_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_e6a07_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_e6a07_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_e6a07_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_e6a07_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_e6a07_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_e6a07_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e6a07_row0_col0" class="data row0 col0" >813b6a8a-9a43-49b6-afb6-1640f4dd5256</td>
#       <td id="T_e6a07_row0_col1" class="data row0 col1" >Node1</td>
#       <td id="T_e6a07_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_e6a07_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_e6a07_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_e6a07_row0_col5" class="data row0 col5" >default_rocky_8</td>
#       <td id="T_e6a07_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_e6a07_row0_col7" class="data row0 col7" >star-w6.fabric-testbed.net</td>
#       <td id="T_e6a07_row0_col8" class="data row0 col8" >STAR</td>
#       <td id="T_e6a07_row0_col9" class="data row0 col9" >rocky</td>
#       <td id="T_e6a07_row0_col10" class="data row0 col10" >2001:400:a100:3030:f816:3eff:fe1c:34eb</td>
#       <td id="T_e6a07_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_e6a07_row0_col12" class="data row0 col12" ></td>
#       <td id="T_e6a07_row0_col13" class="data row0 col13" >ssh -i /home/fabric/work/fabric_config/mcevik_fabric_sliver_1 -F /home/fabric/work/fabric_config/ssh_config rocky@2001:400:a100:3030:f816:3eff:fe1c:34eb</td>
#       <td id="T_e6a07_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/mcevik_fabric_sliver_1.pub</td>
#       <td id="T_e6a07_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/mcevik_fabric_sliver_1</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_57016 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_57016 th {
#   text-align: left;
# }
# #T_57016 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_57016 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_57016 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_57016_row0_col0, #T_57016_row0_col1, #T_57016_row0_col2, #T_57016_row0_col3, #T_57016_row0_col4, #T_57016_row0_col5, #T_57016_row0_col6 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_57016_row0_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_57016_row0_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_57016">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_57016_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_57016_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_57016_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_57016_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_57016_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_57016_level0_col5" class="col_heading level0 col5" >Subnet</th>
#       <th id="T_57016_level0_col6" class="col_heading level0 col6" >Gateway</th>
#       <th id="T_57016_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_57016_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_57016_row0_col0" class="data row0 col0" >0204e3e2-c4ba-4996-9706-0620a1f0d622</td>
#       <td id="T_57016_row0_col1" class="data row0 col1" >net_facility_port</td>
#       <td id="T_57016_row0_col2" class="data row0 col2" >L2</td>
#       <td id="T_57016_row0_col3" class="data row0 col3" >L2STS</td>
#       <td id="T_57016_row0_col4" class="data row0 col4" >None</td>
#       <td id="T_57016_row0_col5" class="data row0 col5" >None</td>
#       <td id="T_57016_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_57016_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_57016_row0_col8" class="data row0 col8" ></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_2a476 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_2a476 th {
#   text-align: left;
# }
# #T_2a476 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_2a476 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_2a476 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_2a476_row0_col0, #T_2a476_row0_col1, #T_2a476_row0_col2, #T_2a476_row0_col3, #T_2a476_row0_col4, #T_2a476_row0_col5, #T_2a476_row0_col6, #T_2a476_row0_col7, #T_2a476_row0_col8, #T_2a476_row0_col9, #T_2a476_row0_col10, #T_2a476_row0_col11, #T_2a476_row0_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_2a476">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_2a476_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_2a476_level0_col1" class="col_heading level0 col1" >Short Name</th>
#       <th id="T_2a476_level0_col2" class="col_heading level0 col2" >Node</th>
#       <th id="T_2a476_level0_col3" class="col_heading level0 col3" >Network</th>
#       <th id="T_2a476_level0_col4" class="col_heading level0 col4" >Bandwidth</th>
#       <th id="T_2a476_level0_col5" class="col_heading level0 col5" >Mode</th>
#       <th id="T_2a476_level0_col6" class="col_heading level0 col6" >VLAN</th>
#       <th id="T_2a476_level0_col7" class="col_heading level0 col7" >MAC</th>
#       <th id="T_2a476_level0_col8" class="col_heading level0 col8" >Physical Device</th>
#       <th id="T_2a476_level0_col9" class="col_heading level0 col9" >Device</th>
#       <th id="T_2a476_level0_col10" class="col_heading level0 col10" >IP Address</th>
#       <th id="T_2a476_level0_col11" class="col_heading level0 col11" >Numa Node</th>
#       <th id="T_2a476_level0_col12" class="col_heading level0 col12" >Switch Port</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2a476_row0_col0" class="data row0 col0" >Node1-nic1-p1</td>
#       <td id="T_2a476_row0_col1" class="data row0 col1" >p1</td>
#       <td id="T_2a476_row0_col2" class="data row0 col2" >Node1</td>
#       <td id="T_2a476_row0_col3" class="data row0 col3" >net_facility_port</td>
#       <td id="T_2a476_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_2a476_row0_col5" class="data row0 col5" >config</td>
#       <td id="T_2a476_row0_col6" class="data row0 col6" ></td>
#       <td id="T_2a476_row0_col7" class="data row0 col7" >02:A9:BF:EC:7F:C7</td>
#       <td id="T_2a476_row0_col8" class="data row0 col8" >eth1</td>
#       <td id="T_2a476_row0_col9" class="data row0 col9" >eth1</td>
#       <td id="T_2a476_row0_col10" class="data row0 col10" >fe80::27e1:577f:6571:6ef5</td>
#       <td id="T_2a476_row0_col11" class="data row0 col11" >4</td>
#       <td id="T_2a476_row0_col12" class="data row0 col12" >HundredGigE0/0/0/3</td>
#     </tr>
#   </tbody>
# </table>
# Time to print interfaces 273 seconds

# %% [markdown]
# ## Observe the Slice's Attributes

# %%
slice = fablib.get_slice(slice_name)

# %%
slice.show()
slice.list_nodes()
slice.list_networks()
slice.list_interfaces()
# Out:
# <style type="text/css">
# #T_1deb0 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_1deb0 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_1deb0 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_1deb0_row0_col0, #T_1deb0_row0_col1, #T_1deb0_row1_col0, #T_1deb0_row1_col1, #T_1deb0_row2_col0, #T_1deb0_row2_col1, #T_1deb0_row3_col0, #T_1deb0_row3_col1, #T_1deb0_row4_col0, #T_1deb0_row4_col1, #T_1deb0_row5_col0, #T_1deb0_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_1deb0">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1deb0_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_1deb0_row0_col1" class="data row0 col1" >ac215229-873c-4107-b4d3-96ed9a90a107</td>
#     </tr>
#     <tr>
#       <td id="T_1deb0_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_1deb0_row1_col1" class="data row1 col1" >Slice-AWSDX</td>
#     </tr>
#     <tr>
#       <td id="T_1deb0_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_1deb0_row2_col1" class="data row2 col1" >2024-10-04 17:28:55 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_1deb0_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_1deb0_row3_col1" class="data row3 col1" >2024-10-03 17:28:55 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_1deb0_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_1deb0_row4_col1" class="data row4 col1" >990d8a8b-7e50-4d13-a3be-0f133ffa8653</td>
#     </tr>
#     <tr>
#       <td id="T_1deb0_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_1deb0_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d7496 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_d7496 th {
#   text-align: left;
# }
# #T_d7496 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_d7496 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_d7496 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_d7496_row0_col0, #T_d7496_row0_col1, #T_d7496_row0_col2, #T_d7496_row0_col3, #T_d7496_row0_col4, #T_d7496_row0_col5, #T_d7496_row0_col6, #T_d7496_row0_col7, #T_d7496_row0_col8, #T_d7496_row0_col9, #T_d7496_row0_col10, #T_d7496_row0_col11, #T_d7496_row0_col12, #T_d7496_row0_col13, #T_d7496_row0_col14, #T_d7496_row0_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_d7496">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_d7496_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_d7496_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_d7496_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_d7496_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_d7496_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_d7496_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_d7496_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_d7496_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_d7496_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_d7496_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_d7496_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_d7496_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_d7496_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_d7496_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_d7496_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_d7496_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d7496_row0_col0" class="data row0 col0" >813b6a8a-9a43-49b6-afb6-1640f4dd5256</td>
#       <td id="T_d7496_row0_col1" class="data row0 col1" >Node1</td>
#       <td id="T_d7496_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_d7496_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_d7496_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_d7496_row0_col5" class="data row0 col5" >default_rocky_8</td>
#       <td id="T_d7496_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_d7496_row0_col7" class="data row0 col7" >star-w6.fabric-testbed.net</td>
#       <td id="T_d7496_row0_col8" class="data row0 col8" >STAR</td>
#       <td id="T_d7496_row0_col9" class="data row0 col9" >rocky</td>
#       <td id="T_d7496_row0_col10" class="data row0 col10" >2001:400:a100:3030:f816:3eff:fe1c:34eb</td>
#       <td id="T_d7496_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_d7496_row0_col12" class="data row0 col12" ></td>
#       <td id="T_d7496_row0_col13" class="data row0 col13" >ssh -i /home/fabric/work/fabric_config/mcevik_fabric_sliver_1 -F /home/fabric/work/fabric_config/ssh_config rocky@2001:400:a100:3030:f816:3eff:fe1c:34eb</td>
#       <td id="T_d7496_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/mcevik_fabric_sliver_1.pub</td>
#       <td id="T_d7496_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/mcevik_fabric_sliver_1</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_5689a caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_5689a th {
#   text-align: left;
# }
# #T_5689a tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_5689a tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_5689a .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_5689a_row0_col0, #T_5689a_row0_col1, #T_5689a_row0_col2, #T_5689a_row0_col3, #T_5689a_row0_col4, #T_5689a_row0_col5, #T_5689a_row0_col6, #T_5689a_row0_col7, #T_5689a_row0_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_5689a">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_5689a_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_5689a_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_5689a_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_5689a_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_5689a_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_5689a_level0_col5" class="col_heading level0 col5" >Subnet</th>
#       <th id="T_5689a_level0_col6" class="col_heading level0 col6" >Gateway</th>
#       <th id="T_5689a_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_5689a_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5689a_row0_col0" class="data row0 col0" >0204e3e2-c4ba-4996-9706-0620a1f0d622</td>
#       <td id="T_5689a_row0_col1" class="data row0 col1" >net_facility_port</td>
#       <td id="T_5689a_row0_col2" class="data row0 col2" >L2</td>
#       <td id="T_5689a_row0_col3" class="data row0 col3" >L2STS</td>
#       <td id="T_5689a_row0_col4" class="data row0 col4" >None</td>
#       <td id="T_5689a_row0_col5" class="data row0 col5" >None</td>
#       <td id="T_5689a_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_5689a_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_5689a_row0_col8" class="data row0 col8" ></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_82bae caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_82bae th {
#   text-align: left;
# }
# #T_82bae tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_82bae tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_82bae .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_82bae_row0_col0, #T_82bae_row0_col1, #T_82bae_row0_col2, #T_82bae_row0_col3, #T_82bae_row0_col4, #T_82bae_row0_col5, #T_82bae_row0_col6, #T_82bae_row0_col7, #T_82bae_row0_col8, #T_82bae_row0_col9, #T_82bae_row0_col10, #T_82bae_row0_col11, #T_82bae_row0_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_82bae">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_82bae_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_82bae_level0_col1" class="col_heading level0 col1" >Short Name</th>
#       <th id="T_82bae_level0_col2" class="col_heading level0 col2" >Node</th>
#       <th id="T_82bae_level0_col3" class="col_heading level0 col3" >Network</th>
#       <th id="T_82bae_level0_col4" class="col_heading level0 col4" >Bandwidth</th>
#       <th id="T_82bae_level0_col5" class="col_heading level0 col5" >Mode</th>
#       <th id="T_82bae_level0_col6" class="col_heading level0 col6" >VLAN</th>
#       <th id="T_82bae_level0_col7" class="col_heading level0 col7" >MAC</th>
#       <th id="T_82bae_level0_col8" class="col_heading level0 col8" >Physical Device</th>
#       <th id="T_82bae_level0_col9" class="col_heading level0 col9" >Device</th>
#       <th id="T_82bae_level0_col10" class="col_heading level0 col10" >IP Address</th>
#       <th id="T_82bae_level0_col11" class="col_heading level0 col11" >Numa Node</th>
#       <th id="T_82bae_level0_col12" class="col_heading level0 col12" >Switch Port</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_82bae_row0_col0" class="data row0 col0" >Node1-nic1-p1</td>
#       <td id="T_82bae_row0_col1" class="data row0 col1" >p1</td>
#       <td id="T_82bae_row0_col2" class="data row0 col2" >Node1</td>
#       <td id="T_82bae_row0_col3" class="data row0 col3" >net_facility_port</td>
#       <td id="T_82bae_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_82bae_row0_col5" class="data row0 col5" >config</td>
#       <td id="T_82bae_row0_col6" class="data row0 col6" ></td>
#       <td id="T_82bae_row0_col7" class="data row0 col7" >02:A9:BF:EC:7F:C7</td>
#       <td id="T_82bae_row0_col8" class="data row0 col8" >eth1</td>
#       <td id="T_82bae_row0_col9" class="data row0 col9" >eth1</td>
#       <td id="T_82bae_row0_col10" class="data row0 col10" >fe80::27e1:577f:6571:6ef5</td>
#       <td id="T_82bae_row0_col11" class="data row0 col11" >4</td>
#       <td id="T_82bae_row0_col12" class="data row0 col12" >HundredGigE0/0/0/3</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_82bae caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_82bae th {
#   text-align: left;
# }
# #T_82bae tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_82bae tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_82bae .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_82bae_row0_col0, #T_82bae_row0_col1, #T_82bae_row0_col2, #T_82bae_row0_col3, #T_82bae_row0_col4, #T_82bae_row0_col5, #T_82bae_row0_col6, #T_82bae_row0_col7, #T_82bae_row0_col8, #T_82bae_row0_col9, #T_82bae_row0_col10, #T_82bae_row0_col11, #T_82bae_row0_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_82bae">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_82bae_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_82bae_level0_col1" class="col_heading level0 col1" >Short Name</th>
#       <th id="T_82bae_level0_col2" class="col_heading level0 col2" >Node</th>
#       <th id="T_82bae_level0_col3" class="col_heading level0 col3" >Network</th>
#       <th id="T_82bae_level0_col4" class="col_heading level0 col4" >Bandwidth</th>
#       <th id="T_82bae_level0_col5" class="col_heading level0 col5" >Mode</th>
#       <th id="T_82bae_level0_col6" class="col_heading level0 col6" >VLAN</th>
#       <th id="T_82bae_level0_col7" class="col_heading level0 col7" >MAC</th>
#       <th id="T_82bae_level0_col8" class="col_heading level0 col8" >Physical Device</th>
#       <th id="T_82bae_level0_col9" class="col_heading level0 col9" >Device</th>
#       <th id="T_82bae_level0_col10" class="col_heading level0 col10" >IP Address</th>
#       <th id="T_82bae_level0_col11" class="col_heading level0 col11" >Numa Node</th>
#       <th id="T_82bae_level0_col12" class="col_heading level0 col12" >Switch Port</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_82bae_row0_col0" class="data row0 col0" >Node1-nic1-p1</td>
#       <td id="T_82bae_row0_col1" class="data row0 col1" >p1</td>
#       <td id="T_82bae_row0_col2" class="data row0 col2" >Node1</td>
#       <td id="T_82bae_row0_col3" class="data row0 col3" >net_facility_port</td>
#       <td id="T_82bae_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_82bae_row0_col5" class="data row0 col5" >config</td>
#       <td id="T_82bae_row0_col6" class="data row0 col6" ></td>
#       <td id="T_82bae_row0_col7" class="data row0 col7" >02:A9:BF:EC:7F:C7</td>
#       <td id="T_82bae_row0_col8" class="data row0 col8" >eth1</td>
#       <td id="T_82bae_row0_col9" class="data row0 col9" >eth1</td>
#       <td id="T_82bae_row0_col10" class="data row0 col10" >fe80::27e1:577f:6571:6ef5</td>
#       <td id="T_82bae_row0_col11" class="data row0 col11" >4</td>
#       <td id="T_82bae_row0_col12" class="data row0 col12" >HundredGigE0/0/0/3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Run the Experiment
#
# Most experiments will require automated configuration and execution. You can use the fablib library to execute arbitrary commands on your node.
#
# The following code demonstrates how to use fablib to execute a "Hello, FABRIC" bash script. The library uses the bastion and VM keys defined at the top of this notebook to jump through the bastion host and execute the script.

# %%
from ipaddress import ip_address, IPv4Address, IPv6Address, IPv4Network, IPv6Network

# Configure the interface(s) of the VM(s) with designated subnet
subnet = IPv4Network("192.168.1.0/24")
available_ips = list(subnet)[2:]

# %%
node1 = slice.get_node(name=f"Node1")        
node1_iface = node1.get_interface(network_name=f'net_facility_port') 
node1_addr = available_ips.pop(99)
print(f"node1_addr: {node1_addr}")
node1_iface.ip_addr_add(addr=node1_addr, subnet=subnet)

stdout, stderr = node1.execute(f'ip addr show {node1_iface.get_os_interface()}')

stdout, stderr = node1.execute(f'sudo ip link set dev {node1_iface.get_physical_os_interface_name()} up')

stdout, stderr = node1.execute(f'sudo ip link set dev {node1_iface.get_os_interface()} up')
# Out:
# node1_addr: 192.168.1.101
# 3: eth1: <BROADCAST,MULTICAST,UP,LOWER_UP> mtu 1500 qdisc mq state UP group default qlen 1000
#     link/ether 02:a9:bf:ec:7f:c7 brd ff:ff:ff:ff:ff:ff
#     altname enp7s0
#     inet 192.168.1.101/24 scope global eth1
#        valid_lft forever preferred_lft forever
#     inet6 fe80::27e1:577f:6571:6ef5/64 scope link noprefixroute
#        valid_lft forever preferred_lft forever

# %%
# Ping the node(s) that are active on the Facility Port side (e.g 192.168.1.10)
node1 = slice.get_node(name=f"Node1")     
node1_iface = node1.get_interface(network_name=f'net_facility_port') 

stdout, stderr = node1.execute(f'ping -c 5 192.168.1.10')

# %% [markdown]
# ## Delete the Slice
#
# Please delete your slice when you are done with your experiment.

# %%
slice.delete()
