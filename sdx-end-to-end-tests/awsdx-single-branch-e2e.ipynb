# %% [markdown]
# # AWSDX - Single Server > sdx-continuous-development
# #### (derived from) Functional Test 3.2.1 - Local bridge with Shared NICs
#
# This Jupyter notebook will allow you to create VMs on different sites and worker nodes consistent with requirements for test 3.2.1 for testing Shared NIC with a local bridge.
#
# ## Step 1:  Configure the Environment
#
# Before running this notebook, you will need to configure your environment using the [Configure Environment](../../fablib_api/configure_environment/configure_environment.ipynb) notebook. Please stop here, open and run that notebook, then return to this notebook.
#
# **This only needs to be done once.**

# %% [markdown]
# ## Step 2: Import the FABlib Library

# %%
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

# Update this line to specify your project id
project_id = "7a4f766f-c8f1-4999-a4df-d53a8930265e"

# Uncomment the line below if using 'FABRIC Tutorials' Project
#project_id="a7818636-1fa1-4e77-bb03-d171598b0862"

fablib = fablib_manager(project_id=project_id)

fablib.show_config()
# Out:
# User: yxin@email.unc.edu bastion key is valid!
# Configuration is valid
# <style type="text/css">
# #T_2736e tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_2736e tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_2736e caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_2736e_row0_col0, #T_2736e_row0_col1, #T_2736e_row1_col0, #T_2736e_row1_col1, #T_2736e_row2_col0, #T_2736e_row2_col1, #T_2736e_row3_col0, #T_2736e_row3_col1, #T_2736e_row4_col0, #T_2736e_row4_col1, #T_2736e_row5_col0, #T_2736e_row5_col1, #T_2736e_row6_col0, #T_2736e_row6_col1, #T_2736e_row7_col0, #T_2736e_row7_col1, #T_2736e_row8_col0, #T_2736e_row8_col1, #T_2736e_row9_col0, #T_2736e_row9_col1, #T_2736e_row10_col0, #T_2736e_row10_col1, #T_2736e_row11_col0, #T_2736e_row11_col1, #T_2736e_row12_col0, #T_2736e_row12_col1, #T_2736e_row13_col0, #T_2736e_row13_col1, #T_2736e_row14_col0, #T_2736e_row14_col1, #T_2736e_row15_col0, #T_2736e_row15_col1, #T_2736e_row16_col0, #T_2736e_row16_col1, #T_2736e_row17_col0, #T_2736e_row17_col1, #T_2736e_row18_col0, #T_2736e_row18_col1, #T_2736e_row19_col0, #T_2736e_row19_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_2736e">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2736e_row0_col0" class="data row0 col0" >Orchestrator</td>
#       <td id="T_2736e_row0_col1" class="data row0 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row1_col0" class="data row1 col0" >Credential Manager</td>
#       <td id="T_2736e_row1_col1" class="data row1 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row2_col0" class="data row2 col0" >Core API</td>
#       <td id="T_2736e_row2_col1" class="data row2 col1" >uis.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row3_col0" class="data row3 col0" >Artifact Manager</td>
#       <td id="T_2736e_row3_col1" class="data row3 col1" >artifacts.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row4_col0" class="data row4 col0" >Token File</td>
#       <td id="T_2736e_row4_col1" class="data row4 col1" >/home/fabric/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row5_col0" class="data row5 col0" >Project ID</td>
#       <td id="T_2736e_row5_col1" class="data row5 col1" >7a4f766f-c8f1-4999-a4df-d53a8930265e</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row6_col0" class="data row6 col0" >Bastion Host</td>
#       <td id="T_2736e_row6_col1" class="data row6 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row7_col0" class="data row7 col0" >Bastion Username</td>
#       <td id="T_2736e_row7_col1" class="data row7 col1" >yxin_0008060646</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row8_col0" class="data row8 col0" >Bastion Private Key File</td>
#       <td id="T_2736e_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row9_col0" class="data row9 col0" >Slice Public Key File</td>
#       <td id="T_2736e_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row10_col0" class="data row10 col0" >Slice Private Key File</td>
#       <td id="T_2736e_row10_col1" class="data row10 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row11_col0" class="data row11 col0" >Sites to avoid</td>
#       <td id="T_2736e_row11_col1" class="data row11 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row12_col0" class="data row12 col0" >SSH Command Line</td>
#       <td id="T_2736e_row12_col1" class="data row12 col1" >ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row13_col0" class="data row13 col0" >Log Level</td>
#       <td id="T_2736e_row13_col1" class="data row13 col1" >INFO</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row14_col0" class="data row14 col0" >Log File</td>
#       <td id="T_2736e_row14_col1" class="data row14 col1" >/tmp/fablib/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row15_col0" class="data row15 col0" >Bastion SSH Config File</td>
#       <td id="T_2736e_row15_col1" class="data row15 col1" >/home/fabric/work/fabric_config/ssh_config</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row16_col0" class="data row16 col0" >Version</td>
#       <td id="T_2736e_row16_col1" class="data row16 col1" >1.9.0</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row17_col0" class="data row17 col0" >Data directory</td>
#       <td id="T_2736e_row17_col1" class="data row17 col1" >/tmp/fablib</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row18_col0" class="data row18 col0" >Fabric Meta Data Release Tag</td>
#       <td id="T_2736e_row18_col1" class="data row18 col1" >main</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row19_col0" class="data row19 col0" >Project Name</td>
#       <td id="T_2736e_row19_col1" class="data row19 col1" >Network Traffic Time Series Analysis</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_2736e tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_2736e tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_2736e caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_2736e_row0_col0, #T_2736e_row0_col1, #T_2736e_row1_col0, #T_2736e_row1_col1, #T_2736e_row2_col0, #T_2736e_row2_col1, #T_2736e_row3_col0, #T_2736e_row3_col1, #T_2736e_row4_col0, #T_2736e_row4_col1, #T_2736e_row5_col0, #T_2736e_row5_col1, #T_2736e_row6_col0, #T_2736e_row6_col1, #T_2736e_row7_col0, #T_2736e_row7_col1, #T_2736e_row8_col0, #T_2736e_row8_col1, #T_2736e_row9_col0, #T_2736e_row9_col1, #T_2736e_row10_col0, #T_2736e_row10_col1, #T_2736e_row11_col0, #T_2736e_row11_col1, #T_2736e_row12_col0, #T_2736e_row12_col1, #T_2736e_row13_col0, #T_2736e_row13_col1, #T_2736e_row14_col0, #T_2736e_row14_col1, #T_2736e_row15_col0, #T_2736e_row15_col1, #T_2736e_row16_col0, #T_2736e_row16_col1, #T_2736e_row17_col0, #T_2736e_row17_col1, #T_2736e_row18_col0, #T_2736e_row18_col1, #T_2736e_row19_col0, #T_2736e_row19_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_2736e">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2736e_row0_col0" class="data row0 col0" >Orchestrator</td>
#       <td id="T_2736e_row0_col1" class="data row0 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row1_col0" class="data row1 col0" >Credential Manager</td>
#       <td id="T_2736e_row1_col1" class="data row1 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row2_col0" class="data row2 col0" >Core API</td>
#       <td id="T_2736e_row2_col1" class="data row2 col1" >uis.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row3_col0" class="data row3 col0" >Artifact Manager</td>
#       <td id="T_2736e_row3_col1" class="data row3 col1" >artifacts.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row4_col0" class="data row4 col0" >Token File</td>
#       <td id="T_2736e_row4_col1" class="data row4 col1" >/home/fabric/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row5_col0" class="data row5 col0" >Project ID</td>
#       <td id="T_2736e_row5_col1" class="data row5 col1" >7a4f766f-c8f1-4999-a4df-d53a8930265e</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row6_col0" class="data row6 col0" >Bastion Host</td>
#       <td id="T_2736e_row6_col1" class="data row6 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row7_col0" class="data row7 col0" >Bastion Username</td>
#       <td id="T_2736e_row7_col1" class="data row7 col1" >yxin_0008060646</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row8_col0" class="data row8 col0" >Bastion Private Key File</td>
#       <td id="T_2736e_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row9_col0" class="data row9 col0" >Slice Public Key File</td>
#       <td id="T_2736e_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row10_col0" class="data row10 col0" >Slice Private Key File</td>
#       <td id="T_2736e_row10_col1" class="data row10 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row11_col0" class="data row11 col0" >Sites to avoid</td>
#       <td id="T_2736e_row11_col1" class="data row11 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row12_col0" class="data row12 col0" >SSH Command Line</td>
#       <td id="T_2736e_row12_col1" class="data row12 col1" >ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row13_col0" class="data row13 col0" >Log Level</td>
#       <td id="T_2736e_row13_col1" class="data row13 col1" >INFO</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row14_col0" class="data row14 col0" >Log File</td>
#       <td id="T_2736e_row14_col1" class="data row14 col1" >/tmp/fablib/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row15_col0" class="data row15 col0" >Bastion SSH Config File</td>
#       <td id="T_2736e_row15_col1" class="data row15 col1" >/home/fabric/work/fabric_config/ssh_config</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row16_col0" class="data row16 col0" >Version</td>
#       <td id="T_2736e_row16_col1" class="data row16 col1" >1.9.0</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row17_col0" class="data row17 col0" >Data directory</td>
#       <td id="T_2736e_row17_col1" class="data row17 col1" >/tmp/fablib</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row18_col0" class="data row18 col0" >Fabric Meta Data Release Tag</td>
#       <td id="T_2736e_row18_col1" class="data row18 col1" >main</td>
#     </tr>
#     <tr>
#       <td id="T_2736e_row19_col0" class="data row19 col0" >Project Name</td>
#       <td id="T_2736e_row19_col1" class="data row19 col1" >Network Traffic Time Series Analysis</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Step 3: Check your existing slices
#
# Since testing can get confusing, check what slices you actually have. It may print nothing if you have no active slices.

# %%
try:
    for slice in fablib.get_slices():
        print(f"{slice}")
except Exception as e:
    print(f"Exception: {e}")
# Out:
# -----------  -----------------------------------------------------
# Slice Name   AWSDX sdx-continuous-development FIU 2025-08-10-05-53
# Slice ID     07051971-a1c8-4490-b004-9e1809c8d731
# Slice State  StableOK
# Lease End    2025-08-30 05:54:10 +0000
# -----------  -----------------------------------------------------

# %% [markdown]
# ## Step 4: Create the Slice
#
# The following creates two nodes with a shared NIC each. This should be run all worker nodes regardless of type.
#
# Two nodes with one NIC component each are created on different workers.  This example uses components of model `NIC_Basic` which are SR-IOV Virtual Function on a 100 Gpbs Mellanox ConnectX-6 PCI device. The VF is accessed by the node via PCI passthrough.
#
# **Be sure to try different combinations of workers**

# %%
from datetime import datetime
from dateutil import tz

name1='Node1'
nic1_name='SharedNIC1'

site='FIU'
###site='DALL'

# since all workers have a standard naming scheme, you can just change the worker
# to move from worker to worker
#worker1=f'{site.lower()}-w1.fabric-testbed.net'
#worker2=f'{site.lower()}-w2.fabric-testbed.net'

cores=12
ram=36
disk=50

#slice_name=f"AWSDX sdx-continuous-development {site} {datetime.now().strftime('%Y-%m-%d-%H-%M')}"
slice_name = "AWSDX sdx-continuous-development FIU 2025-08-10-05-53"

# %% [markdown]
# ### List of the VM images
#
# Available images on FABRIC Testbed
#
# ```
# +------------------------------+
# | Name                         |
# +------------------------------+
# | default_debian_11            |
# | default_debian_12            |
# | default_rocky_8              |
# | default_rocky_9              |
# | default_ubuntu_20            |
# | default_ubuntu_22            |
# | default_ubuntu_24            |
# | docker_rocky_8               |
# | docker_rocky_9               |
# | docker_ubuntu_20             |
# | docker_ubuntu_22             |
# | docker_ubuntu_24             |
# +------------------------------+
# ```

# %%
try:
    #Create Slice
    print(f'Creating slice {slice_name}')
    slice = fablib.new_slice(name=slice_name)

    # Node1
    node1 = slice.add_node(name=name1, site=site, cores=cores, ram=ram, disk=disk, image="docker_rocky_8")
    iface1 = node1.add_component(model='NIC_Basic', name=nic1_name).get_interfaces()[0]
 
    #Submit Slice Request
    slice.submit()
except Exception as e:
    print(f"Exception: {e}")
# Out:
# Retry: 11, Time: 248 sec
# <style type="text/css">
# #T_49db2 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_49db2 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_49db2 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_49db2_row0_col0, #T_49db2_row0_col1, #T_49db2_row1_col0, #T_49db2_row1_col1, #T_49db2_row2_col0, #T_49db2_row2_col1, #T_49db2_row3_col0, #T_49db2_row3_col1, #T_49db2_row4_col0, #T_49db2_row4_col1, #T_49db2_row5_col0, #T_49db2_row6_col0, #T_49db2_row6_col1, #T_49db2_row7_col0, #T_49db2_row7_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_49db2_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_49db2">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_49db2_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_49db2_row0_col1" class="data row0 col1" >07051971-a1c8-4490-b004-9e1809c8d731</td>
#     </tr>
#     <tr>
#       <td id="T_49db2_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_49db2_row1_col1" class="data row1 col1" >AWSDX sdx-continuous-development FIU 2025-08-10-05-53</td>
#     </tr>
#     <tr>
#       <td id="T_49db2_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_49db2_row2_col1" class="data row2 col1" >2025-08-11 05:54:10 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_49db2_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_49db2_row3_col1" class="data row3 col1" >2025-08-10 05:54:10 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_49db2_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_49db2_row4_col1" class="data row4 col1" >7a4f766f-c8f1-4999-a4df-d53a8930265e</td>
#     </tr>
#     <tr>
#       <td id="T_49db2_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_49db2_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#     <tr>
#       <td id="T_49db2_row6_col0" class="data row6 col0" >Email</td>
#       <td id="T_49db2_row6_col1" class="data row6 col1" >yxin@email.unc.edu</td>
#     </tr>
#     <tr>
#       <td id="T_49db2_row7_col0" class="data row7 col0" >UserId</td>
#       <td id="T_49db2_row7_col1" class="data row7 col1" >4628c0be-4d16-42b4-8dc7-716ca422895a</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_78744 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_78744 th {
#   text-align: left;
# }
# #T_78744 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_78744 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_78744 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_78744_row0_col0, #T_78744_row0_col1, #T_78744_row0_col2, #T_78744_row0_col3, #T_78744_row0_col4, #T_78744_row0_col5, #T_78744_row0_col6, #T_78744_row0_col7, #T_78744_row0_col8, #T_78744_row0_col9, #T_78744_row0_col10, #T_78744_row0_col13, #T_78744_row0_col14, #T_78744_row0_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_78744_row0_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_78744_row0_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_78744">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_78744_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_78744_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_78744_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_78744_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_78744_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_78744_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_78744_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_78744_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_78744_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_78744_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_78744_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_78744_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_78744_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_78744_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_78744_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_78744_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_78744_row0_col0" class="data row0 col0" >a83e2ddf-c767-492e-8eaa-9166bbb3115e</td>
#       <td id="T_78744_row0_col1" class="data row0 col1" >Node1</td>
#       <td id="T_78744_row0_col2" class="data row0 col2" >10</td>
#       <td id="T_78744_row0_col3" class="data row0 col3" >32</td>
#       <td id="T_78744_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_78744_row0_col5" class="data row0 col5" >docker_rocky_8</td>
#       <td id="T_78744_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_78744_row0_col7" class="data row0 col7" >fiu-w2.fabric-testbed.net</td>
#       <td id="T_78744_row0_col8" class="data row0 col8" >FIU</td>
#       <td id="T_78744_row0_col9" class="data row0 col9" >rocky</td>
#       <td id="T_78744_row0_col10" class="data row0 col10" >131.94.57.33</td>
#       <td id="T_78744_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_78744_row0_col12" class="data row0 col12" ></td>
#       <td id="T_78744_row0_col13" class="data row0 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@131.94.57.33</td>
#       <td id="T_78744_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_78744_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#   </tbody>
# </table>
# None
# <style type="text/css">
# #T_5e91a caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_5e91a th {
#   text-align: left;
# }
# #T_5e91a tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_5e91a tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_5e91a .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_5e91a_row0_col0, #T_5e91a_row0_col1, #T_5e91a_row0_col2, #T_5e91a_row0_col3, #T_5e91a_row0_col4, #T_5e91a_row0_col5, #T_5e91a_row0_col6, #T_5e91a_row0_col7, #T_5e91a_row0_col8, #T_5e91a_row0_col9, #T_5e91a_row0_col10, #T_5e91a_row0_col11, #T_5e91a_row0_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_5e91a">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_5e91a_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_5e91a_level0_col1" class="col_heading level0 col1" >Short Name</th>
#       <th id="T_5e91a_level0_col2" class="col_heading level0 col2" >Node</th>
#       <th id="T_5e91a_level0_col3" class="col_heading level0 col3" >Network</th>
#       <th id="T_5e91a_level0_col4" class="col_heading level0 col4" >Bandwidth</th>
#       <th id="T_5e91a_level0_col5" class="col_heading level0 col5" >Mode</th>
#       <th id="T_5e91a_level0_col6" class="col_heading level0 col6" >VLAN</th>
#       <th id="T_5e91a_level0_col7" class="col_heading level0 col7" >MAC</th>
#       <th id="T_5e91a_level0_col8" class="col_heading level0 col8" >Physical Device</th>
#       <th id="T_5e91a_level0_col9" class="col_heading level0 col9" >Device</th>
#       <th id="T_5e91a_level0_col10" class="col_heading level0 col10" >IP Address</th>
#       <th id="T_5e91a_level0_col11" class="col_heading level0 col11" >Numa Node</th>
#       <th id="T_5e91a_level0_col12" class="col_heading level0 col12" >Switch Port</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5e91a_row0_col0" class="data row0 col0" >Node1-SharedNIC1-p1</td>
#       <td id="T_5e91a_row0_col1" class="data row0 col1" >p1</td>
#       <td id="T_5e91a_row0_col2" class="data row0 col2" >Node1</td>
#       <td id="T_5e91a_row0_col3" class="data row0 col3" >None</td>
#       <td id="T_5e91a_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_5e91a_row0_col5" class="data row0 col5" >config</td>
#       <td id="T_5e91a_row0_col6" class="data row0 col6" ></td>
#       <td id="T_5e91a_row0_col7" class="data row0 col7" >06:93:08:45:0E:E2</td>
#       <td id="T_5e91a_row0_col8" class="data row0 col8" >enp7s0</td>
#       <td id="T_5e91a_row0_col9" class="data row0 col9" >enp7s0</td>
#       <td id="T_5e91a_row0_col10" class="data row0 col10" >None</td>
#       <td id="T_5e91a_row0_col11" class="data row0 col11" >6</td>
#       <td id="T_5e91a_row0_col12" class="data row0 col12" >None</td>
#     </tr>
#   </tbody>
# </table>
# Time to print interfaces 249 seconds

# %% [markdown]
# ## Step 5: Observe the Slice's Attributes
#
# ### Print the slice

# %%
try:
    slice = fablib.get_slice(name=slice_name)
    print(f"{slice}")
except Exception as e:
    print(f"Exception: {e}")
# Out:
# -----------  -----------------------------------------------------
# Slice Name   AWSDX sdx-continuous-development FIU 2025-08-10-05-53
# Slice ID     07051971-a1c8-4490-b004-9e1809c8d731
# Slice State  StableOK
# Lease End    2025-08-30 05:54:10 +0000
# -----------  -----------------------------------------------------

# %% [markdown]
# ## Print the Node List

# %%
try:
    slice = fablib.get_slice(name=slice_name)

    print(f"{slice.list_nodes()}")
except Exception as e:
    print(f"Exception: {e}")
# Out:
# <style type="text/css">
# #T_9d0ed caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_9d0ed th {
#   text-align: left;
# }
# #T_9d0ed tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_9d0ed tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_9d0ed .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_9d0ed_row0_col0, #T_9d0ed_row0_col1, #T_9d0ed_row0_col2, #T_9d0ed_row0_col3, #T_9d0ed_row0_col4, #T_9d0ed_row0_col5, #T_9d0ed_row0_col6, #T_9d0ed_row0_col7, #T_9d0ed_row0_col8, #T_9d0ed_row0_col9, #T_9d0ed_row0_col10, #T_9d0ed_row0_col11, #T_9d0ed_row0_col12, #T_9d0ed_row0_col13, #T_9d0ed_row0_col14, #T_9d0ed_row0_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_9d0ed">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_9d0ed_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_9d0ed_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_9d0ed_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_9d0ed_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_9d0ed_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_9d0ed_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_9d0ed_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_9d0ed_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_9d0ed_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_9d0ed_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_9d0ed_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_9d0ed_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_9d0ed_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_9d0ed_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_9d0ed_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_9d0ed_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9d0ed_row0_col0" class="data row0 col0" >a83e2ddf-c767-492e-8eaa-9166bbb3115e</td>
#       <td id="T_9d0ed_row0_col1" class="data row0 col1" >Node1</td>
#       <td id="T_9d0ed_row0_col2" class="data row0 col2" >10</td>
#       <td id="T_9d0ed_row0_col3" class="data row0 col3" >32</td>
#       <td id="T_9d0ed_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_9d0ed_row0_col5" class="data row0 col5" >docker_rocky_8</td>
#       <td id="T_9d0ed_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_9d0ed_row0_col7" class="data row0 col7" >fiu-w2.fabric-testbed.net</td>
#       <td id="T_9d0ed_row0_col8" class="data row0 col8" >FIU</td>
#       <td id="T_9d0ed_row0_col9" class="data row0 col9" >rocky</td>
#       <td id="T_9d0ed_row0_col10" class="data row0 col10" >131.94.57.33</td>
#       <td id="T_9d0ed_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_9d0ed_row0_col12" class="data row0 col12" ></td>
#       <td id="T_9d0ed_row0_col13" class="data row0 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@131.94.57.33</td>
#       <td id="T_9d0ed_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_9d0ed_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#   </tbody>
# </table>
# <pandas.io.formats.style.Styler object at 0x7987ec7cba90>

# %% [markdown]
# ## Print the Node Details

# %%
try:
    slice = fablib.get_slice(name=slice_name)
    for node in slice.get_nodes():
        print(f"{node}")
except Exception as e:
    print(f"Exception: {e}")
# Out:
# -----------------  -----------------------------------------------------------------------------------------------------------------
# ID                 a83e2ddf-c767-492e-8eaa-9166bbb3115e
# Name               Node1
# Cores              10
# RAM                32
# Disk               100
# Image              docker_rocky_8
# Image Type         qcow2
# Host               fiu-w2.fabric-testbed.net
# Site               FIU
# Management IP      131.94.57.33
# Reservation State  Active
# Error Message
# SSH Command        ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@131.94.57.33
# -----------------  -----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Print the Interfaces

# %% [markdown]
# You should see 2 interfaces.

# %%
try:
    slice = fablib.get_slice(name=slice_name)
    
    print(f"{slice.list_interfaces()}")
except Exception as e:
    print(f"Exception: {e}")
# Out:
# <style type="text/css">
# #T_79a3d caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_79a3d th {
#   text-align: left;
# }
# #T_79a3d tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_79a3d tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_79a3d .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_79a3d_row0_col0, #T_79a3d_row0_col1, #T_79a3d_row0_col2, #T_79a3d_row0_col3, #T_79a3d_row0_col4, #T_79a3d_row0_col5, #T_79a3d_row0_col6, #T_79a3d_row0_col7, #T_79a3d_row0_col8, #T_79a3d_row0_col9, #T_79a3d_row0_col10, #T_79a3d_row0_col11, #T_79a3d_row0_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_79a3d">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_79a3d_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_79a3d_level0_col1" class="col_heading level0 col1" >Short Name</th>
#       <th id="T_79a3d_level0_col2" class="col_heading level0 col2" >Node</th>
#       <th id="T_79a3d_level0_col3" class="col_heading level0 col3" >Network</th>
#       <th id="T_79a3d_level0_col4" class="col_heading level0 col4" >Bandwidth</th>
#       <th id="T_79a3d_level0_col5" class="col_heading level0 col5" >Mode</th>
#       <th id="T_79a3d_level0_col6" class="col_heading level0 col6" >VLAN</th>
#       <th id="T_79a3d_level0_col7" class="col_heading level0 col7" >MAC</th>
#       <th id="T_79a3d_level0_col8" class="col_heading level0 col8" >Physical Device</th>
#       <th id="T_79a3d_level0_col9" class="col_heading level0 col9" >Device</th>
#       <th id="T_79a3d_level0_col10" class="col_heading level0 col10" >IP Address</th>
#       <th id="T_79a3d_level0_col11" class="col_heading level0 col11" >Numa Node</th>
#       <th id="T_79a3d_level0_col12" class="col_heading level0 col12" >Switch Port</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_79a3d_row0_col0" class="data row0 col0" >Node1-SharedNIC1-p1</td>
#       <td id="T_79a3d_row0_col1" class="data row0 col1" >p1</td>
#       <td id="T_79a3d_row0_col2" class="data row0 col2" >Node1</td>
#       <td id="T_79a3d_row0_col3" class="data row0 col3" >None</td>
#       <td id="T_79a3d_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_79a3d_row0_col5" class="data row0 col5" >config</td>
#       <td id="T_79a3d_row0_col6" class="data row0 col6" ></td>
#       <td id="T_79a3d_row0_col7" class="data row0 col7" >06:93:08:45:0E:E2</td>
#       <td id="T_79a3d_row0_col8" class="data row0 col8" >enp7s0</td>
#       <td id="T_79a3d_row0_col9" class="data row0 col9" >enp7s0</td>
#       <td id="T_79a3d_row0_col10" class="data row0 col10" >None</td>
#       <td id="T_79a3d_row0_col11" class="data row0 col11" >6</td>
#       <td id="T_79a3d_row0_col12" class="data row0 col12" >None</td>
#     </tr>
#   </tbody>
# </table>
# <pandas.io.formats.style.Styler object at 0x797148382550>

# %% [markdown]
# ## Step 6: Configure interfaces, test reachability

# %% [markdown]
# ##  Configure IP Addresses
#
# ### Pick a Subnet
#
# Create a subnet and list of available IP addresses. You can use either IPv4 or IPv6 subnets and addresses.

# %%
from ipaddress import ip_address, IPv4Address, IPv6Address, IPv4Network, IPv6Network

try:
    subnet = IPv4Network("192.168.1.0/24")
    available_ips = list(subnet)[1:]
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ### Configure Node1
#
# Get the node and the interface you wish to configure.  You can use `node.get_interface` to get the interface that is connected to the specified network.  Then `pop` an IP address from the list of available IPs and call `iface.ip_addr_add` to set the IP and subnet.
#
# Optionally, use the `node.execute()` method to show the results of adding the IP address.

# %%
node1 = slice.get_node(name=name1) 
node=node1

# %%
try:
    node1 = slice.get_node(name=name1)        
    node1_iface = node1.get_interface(network_name=network_name) 
    node1_addr = available_ips.pop(0)
    node1_iface.ip_addr_add(addr=node1_addr, subnet=subnet)
    
    stdout, stderr = node1.execute(f'ip addr show {node1_iface.get_os_interface()}')
    print (stdout)
    
except Exception as e:
    print(f"Exception: {e}")
# Out:
# Exception: name 'network_name' is not defined

# %% [markdown]
# ## Step 7: Execute sdx-continuous-development
#
# - https://sdx-docs.readthedocs.io/en/latest/sdx_deploy_single_server.html#

# %% [markdown]
# ### Select the node
#
# - node1 : created with the docker_rocky_8 image that already has docker installed. No further action needed for docker installation
# - node2 : created with the default_debian_12 image.  Install docker -> https://docs.docker.com/engine/install/debian/

# %%
node = node1

if node == node1:
    print(f'--- Use Node: {node}')
    commands = list()
    commands.append(f'sudo dnf install -y jq')


for command in commands:
    print(f'Executing {command}')
    stdout, stderr = node.execute(command)
    
print('Done')
# Out:
# --- Use Node: -----------------  -----------------------------------------------------------------------------------------------------------------
# ID                 a83e2ddf-c767-492e-8eaa-9166bbb3115e
# Name               Node1
# Cores              10
# RAM                32
# Disk               100
# Image              docker_rocky_8
# Image Type         qcow2
# Host               fiu-w2.fabric-testbed.net
# Site               FIU
# Management IP      131.94.57.33
# Reservation State  Active
# Error Message
# SSH Command        ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@131.94.57.33
# -----------------  -----------------------------------------------------------------------------------------------------------------
# Executing sudo dnf install -y jq
# Last metadata expiration check: 2:27:40 ago on Fri Aug 22 09:09:10 2025.
# Package jq-1.6-11.el8_10.x86_64 is already installed.
# Dependencies resolved.
# Nothing to do.
# Complete!
# Done

# %% [markdown]
# #### Check Management IP address (IPv4, IPv6)

# %%
import ipaddress

def check_ip_version(ip_address):
    try:
        ip_object = ipaddress.ip_address(ip_address)
        if isinstance(ip_object, ipaddress.IPv4Address):
            return "IPv4"
        elif isinstance(ip_object, ipaddress.IPv6Address):
            return "IPv6"
    except ValueError:
        return "Invalid IP address"

# %% [markdown]
# ### 1. Setup

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Testing - Declarations > </b> sdx-continuous-development
# </div>

# %%
sdx_work_repo = 'https://github.com/atlanticwave-sdx/sdx-continuous-development'
sdx_work_branch = 'main'
repo_dir = 'awsdx/sdx-continuous-development'
docker_compose_dir = repo_dir + '/data-plane'

# %% [markdown]
# ### 2. Checkout

# %%
commands1 = list()
commands1.append(f'[ ! -d ~/{repo_dir} ] && mkdir -p ~/{repo_dir}')
commands1.append(f'cd ~/{repo_dir} && git init && git remote add origin {sdx_work_repo}')
commands1.append(f'cd ~/{repo_dir} && git fetch origin')
commands1.append(f'cd ~/{repo_dir} && git checkout {sdx_work_branch}')


for command in commands1:
    print(f'Executing {command}')
    stdout, stderr = node.execute(command)
    
print('Done')
# Out:
# Executing [ ! -d ~/awsdx/sdx-continuous-development ] && mkdir -p ~/awsdx/sdx-continuous-development
# Executing cd ~/awsdx/sdx-continuous-development && git init && git remote add origin https://github.com/atlanticwave-sdx/sdx-continuous-development
# Reinitialized existing Git repository in /home/rocky/awsdx/sdx-continuous-development/.git/
# error: remote origin already exists.
# Executing cd ~/awsdx/sdx-continuous-development && git fetch origin
# Executing cd ~/awsdx/sdx-continuous-development && git checkout main
# Your branch is up to date with 'origin/main'.
# Already on 'main'
# Done

# %%
sdx_repo = "sdx-controller"
sdx_branch = "456-l2vpn-status-fails-to-change-after-an-intra-domain-link-is-down"
#sdx_branch = "main"

commands2=list()

commands2.append(f'pwd')
commands2.append(f'sudo systemctl start docker')
commands2.append(f'cd ~/{docker_compose_dir} && cp template.env .env')
commands2.append(f'cd ~/{docker_compose_dir} && git clone https://github.com/atlanticwave-sdx/{sdx_repo}; cd {sdx_repo}; git checkout {sdx_branch}; docker build -t {sdx_repo} .; cd ..;')

for command in commands2:
    print(f'Executing {command}')
    stdout, stderr = node.execute(command)
# Out:
# Executing pwd
# /home/rocky
# Executing sudo systemctl start docker
# Executing cd ~/awsdx/sdx-continuous-development/data-plane && cp template.env .env
# Executing cd ~/awsdx/sdx-continuous-development/data-plane && git clone https://github.com/atlanticwave-sdx/sdx-controller; cd sdx-controller; git checkout 456-l2vpn-status-fails-to-change-after-an-intra-domain-link-is-down; docker build -t sdx-controller .; cd ..;
# Cloning into 'sdx-controller'...
# branch '456-l2vpn-status-fails-to-change-after-an-intra-domain-link-is-down' set up to track 'origin/456-l2vpn-status-fails-to-change-after-an-intra-domain-link-is-down'.
# Switched to a new branch '456-l2vpn-status-fails-to-change-after-an-intra-domain-link-is-down'
# #0 building with "default" instance using docker driver
#
# #1 [internal] load build definition from Dockerfile
# #1 transferring dockerfile: 1.19kB done
# #1 DONE 0.0s
#
# #2 [internal] load metadata for docker.io/library/python:3.11-slim-bullseye
# #2 DONE 15.4s
#
# #3 [internal] load .dockerignore
# #3 transferring context: 112B done
# #3 DONE 0.0s
#
# #4 [sdx-builder-image 1/6] FROM docker.io/library/python:3.11-slim-bullseye@sha256:9e25f400253a5fa3191813d6a67eb801ca1e6f012b3bd2588fa6920b59e3eba6
# #4 DONE 0.0s
#
# #5 [internal] load build context
# #5 transferring context: 1.88MB 0.0s done
# #5 DONE 0.0s
#
# #6 [sdx-builder-image 2/6] RUN apt-get update     && apt-get -y upgrade     && apt-get install -y --no-install-recommends gcc python3-dev git     && apt-get clean     && rm -rf /var/lib/apt/lists/*     && mkdir -p /usr/src/app
# #6 CACHED
#
# #7 [sdx-builder-image 3/6] WORKDIR /usr/src/app
# #7 CACHED
#
# #8 [sdx-builder-image 4/6] RUN python -m venv /opt/venv --upgrade-deps
# #8 CACHED
#
# #9 [sdx-builder-image 5/6] COPY . /usr/src/app
# #9 DONE 0.1s
#
# #10 [sdx-builder-image 6/6] RUN pip install --no-cache-dir .[wsgi]
# #10 0.524 Processing /usr/src/app
# #10 0.526   Installing build dependencies: started
# #10 11.01   Installing build dependencies: finished with status 'done'
# #10 11.01   Getting requirements to build wheel: started
# #10 11.14   Getting requirements to build wheel: finished with status 'done'
# #10 11.14   Preparing metadata (pyproject.toml): started
# #10 11.23   Preparing metadata (pyproject.toml): finished with status 'done'
# #10 16.29 Collecting jsonschema==3.2.0 (from sdx-controller==3.1.0.dev2)
# #10 21.33   Downloading jsonschema-3.2.0-py2.py3-none-any.whl.metadata (7.8 kB)
# #10 21.37 Collecting connexion>=2.14.1 (from connexion[swagger-ui]>=2.14.1->sdx-controller==3.1.0.dev2)
# #10 21.38   Downloading connexion-3.2.0-py3-none-any.whl.metadata (12 kB)
# #10 21.40 Collecting asgiref>=3.7.2 (from sdx-controller==3.1.0.dev2)
# #10 21.40   Downloading asgiref-3.9.1-py3-none-any.whl.metadata (9.3 kB)
# #10 21.41 Collecting python_dateutil>=2.8 (from sdx-controller==3.1.0.dev2)
# #10 21.41   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# #10 21.41 Requirement already satisfied: setuptools>=21.0.0 in /opt/venv/lib/python3.11/site-packages (from sdx-controller==3.1.0.dev2) (80.9.0)
# #10 21.42 Collecting pika>=1.2.0 (from sdx-controller==3.1.0.dev2)
# #10 21.43   Downloading pika-1.3.2-py3-none-any.whl.metadata (13 kB)
# #10 21.45 Collecting dataset (from sdx-controller==3.1.0.dev2)
# #10 21.45   Downloading dataset-1.6.2-py2.py3-none-any.whl.metadata (1.9 kB)
# #10 21.77 Collecting pymongo>3.0 (from sdx-controller==3.1.0.dev2)
# #10 21.78   Downloading pymongo-4.14.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# #10 21.79 Collecting sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling (from sdx-controller==3.1.0.dev2)
# #10 21.79   Cloning https://github.com/atlanticwave-sdx/pce (to revision 294-full-path-link-failure-handling) to /tmp/pip-install-4pc20j_3/sdx-pce_6cff5062f4f4470c9d9e23529762880a
# #10 21.79   Running command git clone --filter=blob:none --quiet https://github.com/atlanticwave-sdx/pce /tmp/pip-install-4pc20j_3/sdx-pce_6cff5062f4f4470c9d9e23529762880a
# #10 32.79   Running command git checkout -b 294-full-path-link-failure-handling --track origin/294-full-path-link-failure-handling
# #10 38.11   Switched to a new branch '294-full-path-link-failure-handling'
# #10 38.11   Branch '294-full-path-link-failure-handling' set up to track remote branch '294-full-path-link-failure-handling' from 'origin'.
# #10 38.11   Resolved https://github.com/atlanticwave-sdx/pce to commit 7536ce9bcb4d9bd8096d143634d842678241f921
# #10 38.12   Installing build dependencies: started
# #10 43.55   Installing build dependencies: finished with status 'done'
# #10 43.55   Getting requirements to build wheel: started
# #10 43.66   Getting requirements to build wheel: finished with status 'done'
# #10 43.66   Preparing metadata (pyproject.toml): started
# #10 43.74   Preparing metadata (pyproject.toml): finished with status 'done'
# #10 43.77 Collecting uvicorn (from sdx-controller==3.1.0.dev2)
# #10 43.77   Downloading uvicorn-0.35.0-py3-none-any.whl.metadata (6.5 kB)
# #10 43.91 Collecting matplotlib (from sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 43.91   Downloading matplotlib-3.10.5-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# #10 43.98 Collecting networkx (from sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 43.98   Downloading networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# #10 44.17 Collecting numpy (from sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 44.19   Downloading numpy-2.3.2-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# #10 44.23 Collecting ortools (from sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 44.24   Downloading ortools-9.14.6206-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# #10 44.25 Collecting prtpy (from sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 44.25   Downloading prtpy-0.8.3-py3-none-any.whl.metadata (4.8 kB)
# #10 44.26 Collecting pydot (from sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 44.27   Downloading pydot-4.0.1-py3-none-any.whl.metadata (11 kB)
# #10 44.29 Collecting dataclasses-json (from sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 44.29   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# #10 44.30 Collecting sdx-datamodel@ git+https://github.com/atlanticwave-sdx/datamodel@3.0.0.dev11 (from sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 44.30   Cloning https://github.com/atlanticwave-sdx/datamodel (to revision 3.0.0.dev11) to /tmp/pip-install-4pc20j_3/sdx-datamodel_05f193dde03b40fbb17c154be604623a
# #10 44.30   Running command git clone --filter=blob:none --quiet https://github.com/atlanticwave-sdx/datamodel /tmp/pip-install-4pc20j_3/sdx-datamodel_05f193dde03b40fbb17c154be604623a
# #10 55.20   Resolved https://github.com/atlanticwave-sdx/datamodel to commit cf8d65da0dd3ee177fbdd2c6790e365609e30f5f
# #10 55.21   Installing build dependencies: started
# #10 60.64   Installing build dependencies: finished with status 'done'
# #10 60.64   Getting requirements to build wheel: started
# #10 60.75   Getting requirements to build wheel: finished with status 'done'
# #10 60.75   Preparing metadata (pyproject.toml): started
# #10 60.83   Preparing metadata (pyproject.toml): finished with status 'done'
# #10 60.85 Collecting grenml (from sdx-datamodel@ git+https://github.com/atlanticwave-sdx/datamodel@3.0.0.dev11->sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 60.85   Downloading grenml-1.0.0-py3-none-any.whl.metadata (13 kB)
# #10 60.87 Collecting graphviz (from sdx-datamodel@ git+https://github.com/atlanticwave-sdx/datamodel@3.0.0.dev11->sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 60.87   Downloading graphviz-0.21-py3-none-any.whl.metadata (12 kB)
# #10 60.89 Collecting transitions (from sdx-datamodel@ git+https://github.com/atlanticwave-sdx/datamodel@3.0.0.dev11->sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 60.90   Downloading transitions-0.9.3-py2.py3-none-any.whl.metadata (97 kB)
# #10 60.95 Collecting fastapi (from sdx-datamodel@ git+https://github.com/atlanticwave-sdx/datamodel@3.0.0.dev11->sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 60.95   Downloading fastapi-0.116.1-py3-none-any.whl.metadata (28 kB)
# #10 60.99 Collecting pytz (from sdx-datamodel@ git+https://github.com/atlanticwave-sdx/datamodel@3.0.0.dev11->sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 61.00   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# #10 61.01 Collecting attrs>=17.4.0 (from jsonschema==3.2.0->sdx-controller==3.1.0.dev2)
# #10 61.02   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# #10 61.05 Collecting pyrsistent>=0.14.0 (from jsonschema==3.2.0->sdx-controller==3.1.0.dev2)
# #10 61.06   Downloading pyrsistent-0.20.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (27 kB)
# #10 61.07 Collecting six>=1.11.0 (from jsonschema==3.2.0->sdx-controller==3.1.0.dev2)
# #10 61.08   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# #10 61.10 Collecting Jinja2>=3.0.0 (from connexion>=2.14.1->connexion[swagger-ui]>=2.14.1->sdx-controller==3.1.0.dev2)
# #10 61.11   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# #10 61.14 Collecting PyYAML>=5.1 (from connexion>=2.14.1->connexion[swagger-ui]>=2.14.1->sdx-controller==3.1.0.dev2)
# #10 61.14   Downloading PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# #10 61.16 Collecting httpx>=0.23 (from connexion>=2.14.1->connexion[swagger-ui]>=2.14.1->sdx-controller==3.1.0.dev2)
# #10 61.17   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# #10 61.18 Collecting inflection>=0.3.1 (from connexion>=2.14.1->connexion[swagger-ui]>=2.14.1->sdx-controller==3.1.0.dev2)
# #10 61.18   Downloading inflection-0.5.1-py2.py3-none-any.whl.metadata (1.7 kB)
# #10 61.19 INFO: pip is looking at multiple versions of connexion to determine which version is compatible with other requirements. This could take a while.
# #10 61.19 Collecting connexion>=2.14.1 (from connexion[swagger-ui]>=2.14.1->sdx-controller==3.1.0.dev2)
# #10 61.21   Downloading connexion-3.1.0-py3-none-any.whl.metadata (12 kB)
# #10 61.22   Downloading connexion-3.0.6-py3-none-any.whl.metadata (12 kB)
# #10 61.23   Downloading connexion-3.0.5-py3-none-any.whl.metadata (12 kB)
# #10 61.24   Downloading connexion-3.0.4-py3-none-any.whl.metadata (12 kB)
# #10 61.25   Downloading connexion-3.0.3-py3-none-any.whl.metadata (12 kB)
# #10 61.26   Downloading connexion-3.0.2-py3-none-any.whl.metadata (12 kB)
# #10 61.27   Downloading connexion-3.0.1-py3-none-any.whl.metadata (12 kB)
# #10 61.27 INFO: pip is still looking at multiple versions of connexion to determine which version is compatible with other requirements. This could take a while.
# #10 61.28   Downloading connexion-3.0.0-py3-none-any.whl.metadata (12 kB)
# #10 61.29   Downloading connexion-2.14.2-py2.py3-none-any.whl.metadata (28 kB)
# #10 61.30 Collecting clickclick<21,>=1.2 (from connexion>=2.14.1->connexion[swagger-ui]>=2.14.1->sdx-controller==3.1.0.dev2)
# #10 61.31   Downloading clickclick-20.10.2-py2.py3-none-any.whl.metadata (7.6 kB)
# #10 61.35 Collecting requests<3,>=2.9.1 (from connexion>=2.14.1->connexion[swagger-ui]>=2.14.1->sdx-controller==3.1.0.dev2)
# #10 61.36   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# #10 61.38 Collecting werkzeug<2.3,>=1.0 (from connexion>=2.14.1->connexion[swagger-ui]>=2.14.1->sdx-controller==3.1.0.dev2)
# #10 61.40   Downloading Werkzeug-2.2.3-py3-none-any.whl.metadata (4.4 kB)
# #10 61.42 Collecting packaging>=20 (from connexion>=2.14.1->connexion[swagger-ui]>=2.14.1->sdx-controller==3.1.0.dev2)
# #10 61.42   Downloading packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# #10 61.43 Collecting flask<2.3,>=1.0.4 (from connexion>=2.14.1->connexion[swagger-ui]>=2.14.1->sdx-controller==3.1.0.dev2)
# #10 61.45   Downloading Flask-2.2.5-py3-none-any.whl.metadata (3.9 kB)
# #10 61.45 Collecting itsdangerous>=0.24 (from connexion>=2.14.1->connexion[swagger-ui]>=2.14.1->sdx-controller==3.1.0.dev2)
# #10 61.46   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# #10 61.48 Collecting click>=4.0 (from clickclick<21,>=1.2->connexion>=2.14.1->connexion[swagger-ui]>=2.14.1->sdx-controller==3.1.0.dev2)
# #10 61.48   Downloading click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# #10 61.64 Collecting charset_normalizer<4,>=2 (from requests<3,>=2.9.1->connexion>=2.14.1->connexion[swagger-ui]>=2.14.1->sdx-controller==3.1.0.dev2)
# #10 61.64   Downloading charset_normalizer-3.4.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (36 kB)
# #10 61.66 Collecting idna<4,>=2.5 (from requests<3,>=2.9.1->connexion>=2.14.1->connexion[swagger-ui]>=2.14.1->sdx-controller==3.1.0.dev2)
# #10 61.66   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# #10 61.69 Collecting urllib3<3,>=1.21.1 (from requests<3,>=2.9.1->connexion>=2.14.1->connexion[swagger-ui]>=2.14.1->sdx-controller==3.1.0.dev2)
# #10 61.70   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# #10 61.71 Collecting certifi>=2017.4.17 (from requests<3,>=2.9.1->connexion>=2.14.1->connexion[swagger-ui]>=2.14.1->sdx-controller==3.1.0.dev2)
# #10 61.74   Downloading certifi-2025.8.3-py3-none-any.whl.metadata (2.4 kB)
# #10 61.79 Collecting MarkupSafe>=2.1.1 (from werkzeug<2.3,>=1.0->connexion>=2.14.1->connexion[swagger-ui]>=2.14.1->sdx-controller==3.1.0.dev2)
# #10 61.80   Downloading MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# #10 61.81 INFO: pip is looking at multiple versions of connexion[swagger-ui] to determine which version is compatible with other requirements. This could take a while.
# #10 61.82 INFO: pip is still looking at multiple versions of connexion[swagger-ui] to determine which version is compatible with other requirements. This could take a while.
# #10 61.83 Collecting swagger-ui-bundle<0.1,>=0.0.2 (from connexion[swagger-ui]>=2.14.1->sdx-controller==3.1.0.dev2)
# #10 61.86   Downloading swagger_ui_bundle-0.0.9-py3-none-any.whl.metadata (2.8 kB)
# #10 61.88 Collecting dnspython<3.0.0,>=1.16.0 (from pymongo>3.0->sdx-controller==3.1.0.dev2)
# #10 61.89   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# #10 61.95 Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 61.96   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# #10 61.97 Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json->sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 61.97   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# #10 61.99 Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json->sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 61.99   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# #10 62.01 Collecting typing-extensions>=3.7.4 (from typing-inspect<1,>=0.4.0->dataclasses-json->sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 62.01   Downloading typing_extensions-4.14.1-py3-none-any.whl.metadata (3.0 kB)
# #10 62.39 Collecting sqlalchemy<2.0.0,>=1.3.2 (from dataset->sdx-controller==3.1.0.dev2)
# #10 62.40   Downloading SQLAlchemy-1.4.54-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# #10 62.45 Collecting alembic>=0.6.2 (from dataset->sdx-controller==3.1.0.dev2)
# #10 62.46   Downloading alembic-1.16.4-py3-none-any.whl.metadata (7.3 kB)
# #10 62.47 Collecting banal>=1.0.1 (from dataset->sdx-controller==3.1.0.dev2)
# #10 62.48   Downloading banal-1.0.6-py2.py3-none-any.whl.metadata (1.4 kB)
# #10 62.61 Collecting greenlet!=0.4.17 (from sqlalchemy<2.0.0,>=1.3.2->dataset->sdx-controller==3.1.0.dev2)
# #10 62.63   Downloading greenlet-3.2.4-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (4.1 kB)
# #10 62.67 Collecting Mako (from alembic>=0.6.2->dataset->sdx-controller==3.1.0.dev2)
# #10 62.68   Downloading mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# #10 62.72 Collecting starlette<0.48.0,>=0.40.0 (from fastapi->sdx-datamodel@ git+https://github.com/atlanticwave-sdx/datamodel@3.0.0.dev11->sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 62.72   Downloading starlette-0.47.2-py3-none-any.whl.metadata (6.2 kB)
# #10 62.88 Collecting pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 (from fastapi->sdx-datamodel@ git+https://github.com/atlanticwave-sdx/datamodel@3.0.0.dev11->sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 62.89   Downloading pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# #10 62.90 Collecting annotated-types>=0.6.0 (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->sdx-datamodel@ git+https://github.com/atlanticwave-sdx/datamodel@3.0.0.dev11->sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 62.91   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# #10 63.71 Collecting pydantic-core==2.33.2 (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->sdx-datamodel@ git+https://github.com/atlanticwave-sdx/datamodel@3.0.0.dev11->sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 63.72   Downloading pydantic_core-2.33.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# #10 63.74 Collecting typing-inspection>=0.4.0 (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->sdx-datamodel@ git+https://github.com/atlanticwave-sdx/datamodel@3.0.0.dev11->sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 63.74   Downloading typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# #10 63.77 Collecting anyio<5,>=3.6.2 (from starlette<0.48.0,>=0.40.0->fastapi->sdx-datamodel@ git+https://github.com/atlanticwave-sdx/datamodel@3.0.0.dev11->sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 63.77   Downloading anyio-4.10.0-py3-none-any.whl.metadata (4.0 kB)
# #10 63.79 Collecting sniffio>=1.1 (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi->sdx-datamodel@ git+https://github.com/atlanticwave-sdx/datamodel@3.0.0.dev11->sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 63.79   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# #10 63.82 Collecting backports-datetime-fromisoformat~=1.0 (from grenml->sdx-datamodel@ git+https://github.com/atlanticwave-sdx/datamodel@3.0.0.dev11->sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 63.83   Downloading backports-datetime-fromisoformat-1.0.0.tar.gz (10 kB)
# #10 63.83   Installing build dependencies: started
# #10 69.51   Installing build dependencies: finished with status 'done'
# #10 69.51   Getting requirements to build wheel: started
# #10 69.84   Getting requirements to build wheel: finished with status 'done'
# #10 69.85   Preparing metadata (pyproject.toml): started
# #10 70.05   Preparing metadata (pyproject.toml): finished with status 'done'
# #10 70.39 Collecting lxml~=4.9.0 (from grenml->sdx-datamodel@ git+https://github.com/atlanticwave-sdx/datamodel@3.0.0.dev11->sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 70.39   Downloading lxml-4.9.4-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.7 kB)
# #10 70.41 Collecting openpyxl~=3.0 (from grenml->sdx-datamodel@ git+https://github.com/atlanticwave-sdx/datamodel@3.0.0.dev11->sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 70.41   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# #10 70.42 Collecting et-xmlfile (from openpyxl~=3.0->grenml->sdx-datamodel@ git+https://github.com/atlanticwave-sdx/datamodel@3.0.0.dev11->sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 70.43   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# #10 70.51 Collecting contourpy>=1.0.1 (from matplotlib->sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 70.51   Downloading contourpy-1.3.3-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# #10 70.52 Collecting cycler>=0.10 (from matplotlib->sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 70.53   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# #10 70.69 Collecting fonttools>=4.22.0 (from matplotlib->sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 70.69   Downloading fonttools-4.59.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (108 kB)
# #10 70.77 Collecting kiwisolver>=1.3.1 (from matplotlib->sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 70.77   Downloading kiwisolver-1.4.9-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.3 kB)
# #10 70.95 Collecting pillow>=8 (from matplotlib->sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 70.96   Downloading pillow-11.3.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.0 kB)
# #10 70.98 Collecting pyparsing>=2.3.1 (from matplotlib->sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 71.00   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# #10 71.20 Collecting absl-py>=2.0.0 (from ortools->sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 71.24   Downloading absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# #10 71.36 Collecting pandas>=2.0.0 (from ortools->sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 71.37   Downloading pandas-2.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (91 kB)
# #10 71.57 Collecting protobuf<6.32,>=6.31.1 (from ortools->sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 71.57   Downloading protobuf-6.31.1-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# #10 71.58 Collecting immutabledict>=3.0.0 (from ortools->sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 71.59   Downloading immutabledict-4.2.1-py3-none-any.whl.metadata (3.5 kB)
# #10 71.63 Collecting tzdata>=2022.7 (from pandas>=2.0.0->ortools->sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 71.63   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# #10 71.77 Collecting scipy>=1.6.1 (from prtpy->sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 71.78   Downloading scipy-1.16.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (61 kB)
# #10 71.81 Collecting mip>=1.13.0 (from prtpy->sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 71.81   Downloading mip-1.15.0-py3-none-any.whl.metadata (21 kB)
# #10 71.93 Collecting cffi==1.15.* (from mip>=1.13.0->prtpy->sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 71.93   Downloading cffi-1.15.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# #10 71.94 Collecting pycparser (from cffi==1.15.*->mip>=1.13.0->prtpy->sdx-pce@ git+https://github.com/atlanticwave-sdx/pce@294-full-path-link-failure-handling->sdx-controller==3.1.0.dev2)
# #10 71.94   Downloading pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# #10 71.99 Collecting h11>=0.8 (from uvicorn->sdx-controller==3.1.0.dev2)
# #10 71.99   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# #10 72.00 Downloading jsonschema-3.2.0-py2.py3-none-any.whl (56 kB)
# #10 72.00 Downloading asgiref-3.9.1-py3-none-any.whl (23 kB)
# #10 72.01 Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
# #10 72.02 Downloading connexion-2.14.2-py2.py3-none-any.whl (95 kB)
# #10 72.02 Downloading clickclick-20.10.2-py2.py3-none-any.whl (7.4 kB)
# #10 72.03 Downloading Flask-2.2.5-py3-none-any.whl (101 kB)
# #10 72.03 Downloading inflection-0.5.1-py2.py3-none-any.whl (9.5 kB)
# #10 72.03 Downloading PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (762 kB)
# #10 72.04    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.0/763.0 kB 135.8 MB/s  0:00:00
# #10 72.05 Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# #10 72.05 Downloading charset_normalizer-3.4.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (150 kB)
# #10 72.07 Downloading idna-3.10-py3-none-any.whl (70 kB)
# #10 72.07 Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# #10 72.08 Downloading Werkzeug-2.2.3-py3-none-any.whl (233 kB)
# #10 72.08 Downloading certifi-2025.8.3-py3-none-any.whl (161 kB)
# #10 72.09 Downloading click-8.2.1-py3-none-any.whl (102 kB)
# #10 72.10 Downloading swagger_ui_bundle-0.0.9-py3-none-any.whl (6.2 MB)
# #10 72.16    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 103.0 MB/s  0:00:00
# #10 72.16 Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# #10 72.17 Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# #10 72.17 Downloading MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# #10 72.18 Downloading packaging-25.0-py3-none-any.whl (66 kB)
# #10 72.18 Downloading pika-1.3.2-py3-none-any.whl (155 kB)
# #10 72.19 Downloading pymongo-4.14.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
# #10 72.22    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 55.8 MB/s  0:00:00
# #10 72.22 Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
# #10 72.23 Downloading pyrsistent-0.20.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (120 kB)
# #10 72.24 Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# #10 72.24 Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# #10 72.24 Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# #10 72.25 Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
# #10 72.26 Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# #10 72.26 Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# #10 72.26 Downloading typing_extensions-4.14.1-py3-none-any.whl (43 kB)
# #10 72.27 Downloading dataset-1.6.2-py2.py3-none-any.whl (18 kB)
# #10 72.29 Downloading SQLAlchemy-1.4.54-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
# #10 72.32    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 61.8 MB/s  0:00:00
# #10 72.32 Downloading alembic-1.16.4-py3-none-any.whl (247 kB)
# #10 72.33 Downloading banal-1.0.6-py2.py3-none-any.whl (6.1 kB)
# #10 72.33 Downloading greenlet-3.2.4-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (587 kB)
# #10 72.33    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 kB 208.0 MB/s  0:00:00
# #10 72.34 Downloading fastapi-0.116.1-py3-none-any.whl (95 kB)
# #10 72.34 Downloading pydantic-2.11.7-py3-none-any.whl (444 kB)
# #10 72.35 Downloading pydantic_core-2.33.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
# #10 72.37    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 140.5 MB/s  0:00:00
# #10 72.37 Downloading starlette-0.47.2-py3-none-any.whl (72 kB)
# #10 72.38 Downloading anyio-4.10.0-py3-none-any.whl (107 kB)
# #10 72.38 Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# #10 72.39 Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# #10 72.39 Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# #10 72.40 Downloading graphviz-0.21-py3-none-any.whl (47 kB)
# #10 72.40 Downloading grenml-1.0.0-py3-none-any.whl (43 kB)
# #10 72.41 Downloading lxml-4.9.4-cp311-cp311-manylinux_2_28_x86_64.whl (7.9 MB)
# #10 72.58    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 46.1 MB/s  0:00:00
# #10 72.60 Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# #10 72.61 Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# #10 72.62 Downloading mako-1.3.10-py3-none-any.whl (78 kB)
# #10 72.63 Downloading matplotlib-3.10.5-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
# #10 72.76    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 66.2 MB/s  0:00:00
# #10 72.77 Downloading contourpy-1.3.3-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (355 kB)
# #10 72.78 Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# #10 72.78 Downloading fonttools-4.59.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.0 MB)
# #10 72.84    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 88.8 MB/s  0:00:00
# #10 72.89 Downloading kiwisolver-1.4.9-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.4 MB)
# #10 72.94    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 26.7 MB/s  0:00:00
# #10 72.95 Downloading numpy-2.3.2-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.9 MB)
# #10 73.22    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 62.8 MB/s  0:00:00
# #10 73.22 Downloading pillow-11.3.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.6 MB)
# #10 73.39    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 39.2 MB/s  0:00:00
# #10 73.40 Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# #10 73.42 Downloading networkx-3.5-py3-none-any.whl (2.0 MB)
# #10 73.44    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 92.4 MB/s  0:00:00
# #10 73.46 Downloading ortools-9.14.6206-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (27.7 MB)
# #10 73.80    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.7/27.7 MB 82.0 MB/s  0:00:00
# #10 73.83 Downloading protobuf-6.31.1-cp39-abi3-manylinux2014_x86_64.whl (321 kB)
# #10 73.85 Downloading absl_py-2.3.1-py3-none-any.whl (135 kB)
# #10 73.85 Downloading immutabledict-4.2.1-py3-none-any.whl (4.7 kB)
# #10 73.86 Downloading pandas-2.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
# #10 74.09    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 53.8 MB/s  0:00:00
# #10 74.09 Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# #10 74.10 Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# #10 74.11 Downloading prtpy-0.8.3-py3-none-any.whl (64 kB)
# #10 74.12 Downloading mip-1.15.0-py3-none-any.whl (15.3 MB)
# #10 74.39    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 59.1 MB/s  0:00:00
# #10 74.39 Downloading cffi-1.15.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (462 kB)
# #10 74.40 Downloading scipy-1.16.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (35.4 MB)
# #10 74.81    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.4/35.4 MB 86.9 MB/s  0:00:00
# #10 74.81 Downloading pycparser-2.22-py3-none-any.whl (117 kB)
# #10 74.82 Downloading pydot-4.0.1-py3-none-any.whl (37 kB)
# #10 74.82 Downloading transitions-0.9.3-py2.py3-none-any.whl (112 kB)
# #10 74.83 Downloading uvicorn-0.35.0-py3-none-any.whl (66 kB)
# #10 74.83 Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# #10 75.06 Building wheels for collected packages: sdx-controller, sdx-pce, sdx-datamodel, backports-datetime-fromisoformat
# #10 75.06   Building wheel for sdx-controller (pyproject.toml): started
# #10 75.15   Building wheel for sdx-controller (pyproject.toml): finished with status 'done'
# #10 75.15   Created wheel for sdx-controller: filename=sdx_controller-3.1.0.dev2-py3-none-any.whl size=63869 sha256=fb6127240839094b002393e9a7ee07635ca97e8506ac2b29c8222ca58bddf606
# #10 75.15   Stored in directory: /tmp/pip-ephem-wheel-cache-kaiwdq1f/wheels/b2/b1/15/2c9bda2c3541a2c801333072ca58af321ab8c269a465a4a43e
# #10 75.15   Building wheel for sdx-pce (pyproject.toml): started
# #10 75.24   Building wheel for sdx-pce (pyproject.toml): finished with status 'done'
# #10 75.24   Created wheel for sdx-pce: filename=sdx_pce-3.1.0.dev4-py3-none-any.whl size=40842 sha256=687d690580e6c3d2abb94de097d7002ebcf414fdbc8d7382bc37d452f3018bde
# #10 75.24   Stored in directory: /tmp/pip-ephem-wheel-cache-kaiwdq1f/wheels/4e/c8/95/644ce887a2ed3e9bb7964b79f62a32c723b403e051da70f688
# #10 75.24   Building wheel for sdx-datamodel (pyproject.toml): started
# #10 75.35   Building wheel for sdx-datamodel (pyproject.toml): finished with status 'done'
# #10 75.35   Created wheel for sdx-datamodel: filename=sdx_datamodel-3.0.0.dev8-py3-none-any.whl size=233639 sha256=ad2612d6252906b2c9ea8d38669adeddcd52d863536c131c7cb9616d6d71b5f2
# #10 75.35   Stored in directory: /tmp/pip-ephem-wheel-cache-kaiwdq1f/wheels/03/10/39/216f670d3a0b4bff5c1d32007f8d2251a2854b8bf4827443c2
# #10 75.35   Building wheel for backports-datetime-fromisoformat (pyproject.toml): started
# #10 75.94   Building wheel for backports-datetime-fromisoformat (pyproject.toml): finished with status 'done'
# #10 75.94   Created wheel for backports-datetime-fromisoformat: filename=backports_datetime_fromisoformat-1.0.0-cp311-cp311-linux_x86_64.whl size=25666 sha256=5904f0e9a6e2dfabd29af5dcbe4ad187a7e1ee304cc7efd8a7d55d3b54af014f
# #10 75.94   Stored in directory: /tmp/pip-ephem-wheel-cache-kaiwdq1f/wheels/5e/e3/d4/f2303f9c9867c5b802bb70b80b927915fe3fb1205e1a636097
# #10 75.94 Successfully built sdx-controller sdx-pce sdx-datamodel backports-datetime-fromisoformat
# #10 76.12 Installing collected packages: pytz, banal, backports-datetime-fromisoformat, urllib3, tzdata, typing-extensions, sniffio, six, PyYAML, pyrsistent, pyparsing, pycparser, protobuf, pillow, pika, packaging, numpy, networkx, mypy-extensions, MarkupSafe, lxml, kiwisolver, itsdangerous, inflection, immutabledict, idna, h11, greenlet, graphviz, fonttools, et-xmlfile, dnspython, cycler, click, charset_normalizer, certifi, attrs, asgiref, annotated-types, absl-py, werkzeug, uvicorn, typing-inspection, typing-inspect, transitions, sqlalchemy, scipy, requests, python_dateutil, pymongo, pydot, pydantic-core, openpyxl, marshmallow, Mako, jsonschema, Jinja2, contourpy, clickclick, cffi, anyio, swagger-ui-bundle, starlette, pydantic, pandas, mip, matplotlib, grenml, flask, dataclasses-json, alembic, prtpy, ortools, fastapi, dataset, connexion, sdx-datamodel, sdx-pce, sdx-controller
# #10 95.72
# #10 95.73 Successfully installed Jinja2-3.1.6 Mako-1.3.10 MarkupSafe-3.0.2 PyYAML-6.0.2 absl-py-2.3.1 alembic-1.16.4 annotated-types-0.7.0 anyio-4.10.0 asgiref-3.9.1 attrs-25.3.0 backports-datetime-fromisoformat-1.0.0 banal-1.0.6 certifi-2025.8.3 cffi-1.15.1 charset_normalizer-3.4.3 click-8.2.1 clickclick-20.10.2 connexion-2.14.2 contourpy-1.3.3 cycler-0.12.1 dataclasses-json-0.6.7 dataset-1.6.2 dnspython-2.7.0 et-xmlfile-2.0.0 fastapi-0.116.1 flask-2.2.5 fonttools-4.59.1 graphviz-0.21 greenlet-3.2.4 grenml-1.0.0 h11-0.16.0 idna-3.10 immutabledict-4.2.1 inflection-0.5.1 itsdangerous-2.2.0 jsonschema-3.2.0 kiwisolver-1.4.9 lxml-4.9.4 marshmallow-3.26.1 matplotlib-3.10.5 mip-1.15.0 mypy-extensions-1.1.0 networkx-3.5 numpy-2.3.2 openpyxl-3.1.5 ortools-9.14.6206 packaging-25.0 pandas-2.3.2 pika-1.3.2 pillow-11.3.0 protobuf-6.31.1 prtpy-0.8.3 pycparser-2.22 pydantic-2.11.7 pydantic-core-2.33.2 pydot-4.0.1 pymongo-4.14.1 pyparsing-3.2.3 pyrsistent-0.20.0 python_dateutil-2.9.0.post0 pytz-2025.2 requests-2.32.5 scipy-1.16.1 sdx-controller-3.1.0.dev2 sdx-datamodel-3.0.0.dev8 sdx-pce-3.1.0.dev4 six-1.17.0 sniffio-1.3.1 sqlalchemy-1.4.54 starlette-0.47.2 swagger-ui-bundle-0.0.9 transitions-0.9.3 typing-extensions-4.14.1 typing-inspect-0.9.0 typing-inspection-0.4.1 tzdata-2025.2 urllib3-2.5.0 uvicorn-0.35.0 werkzeug-2.2.3
# #10 DONE 102.7s
#
# #4 [sdx-builder-image 1/6] FROM docker.io/library/python:3.11-slim-bullseye@sha256:9e25f400253a5fa3191813d6a67eb801ca1e6f012b3bd2588fa6920b59e3eba6
# #4 CACHED
#
# #11 [sdx-runtime-image 2/2] COPY --from=sdx-builder-image /opt/venv /opt/venv
# #11 DONE 5.5s
#
# #12 exporting to image
# #12 exporting layers
# #12 exporting layers 3.3s done
# #12 writing image sha256:e7314d08fa4afff7f05851165392a4f5d5fcfc4cc1ca86caf4d1657bb128f66c done
# #12 naming to docker.io/library/sdx-controller done
# #12 DONE 3.3s

# %% [markdown]
# ### 3. Start

# %% [markdown]
# ##### ***sdx-continuous-development***

# %%
commands3 = list()
commands3.append(f'cd ~/{docker_compose_dir} && for repo in sdx-lc kytos-sdx; do git -C $repo pull || git clone https://github.com/atlanticwave-sdx/$repo; cd $repo/; docker build -t $repo .; cd ..; done')

for command in commands3:
    print(f'Executing {command}')
    stdout, stderr = node.execute(command)
    
print('Done')
# Out:
# Executing cd ~/awsdx/sdx-continuous-development/data-plane && for repo in sdx-lc kytos-sdx; do git -C $repo pull || git clone https://github.com/atlanticwave-sdx/$repo; cd $repo/; docker build -t $repo .; cd ..; done
# Already up to date.
# #0 building with "default" instance using docker driver
#
# #1 [internal] load build definition from Dockerfile
# #1 transferring dockerfile: 621B done
# #1 DONE 0.0s
#
# #2 [internal] load metadata for docker.io/library/python:3.11-slim-bullseye
# #2 DONE 15.4s
#
# #3 [internal] load .dockerignore
# #3 transferring context: 118B done
# #3 DONE 0.0s
#
# #4 [1/7] FROM docker.io/library/python:3.11-slim-bullseye@sha256:9e25f400253a5fa3191813d6a67eb801ca1e6f012b3bd2588fa6920b59e3eba6
# #4 DONE 0.0s
#
# #5 [internal] load build context
# #5 transferring context: 255.11kB 0.0s done
# #5 DONE 0.0s
#
# #6 [4/7] WORKDIR /usr/src/app
# #6 CACHED
#
# #7 [5/7] COPY . /usr/src/app
# #7 CACHED
#
# #8 [6/7] RUN python3 -m venv /opt/venv --upgrade-deps
# #8 CACHED
#
# #9 [3/7] RUN mkdir -p /usr/src/app
# #9 CACHED
#
# #10 [2/7] RUN apt-get update     && apt-get -y upgrade     && apt-get install -y --no-install-recommends gcc python3-dev git     && apt-get clean     && rm -rf /var/lib/apt/lists/*
# #10 CACHED
#
# #11 [7/7] RUN pip3 install --no-cache-dir .[wsgi]
# #11 CACHED
#
# #12 exporting to image
# #12 exporting layers done
# #12 writing image sha256:f9bf74408ff58a7e40ac8480b4937f9bf7678258efc998374c1345da09aac78a done
# #12 naming to docker.io/library/sdx-lc done
# #12 DONE 0.0s
# Already up to date.
# #0 building with "default" instance using docker driver
#
# #1 [internal] load build definition from Dockerfile
# #1 transferring dockerfile: 259B done
# #1 DONE 0.0s
#
# #2 [internal] load metadata for docker.io/amlight/kytos:latest
# #2 DONE 15.4s
#
# #3 [internal] load .dockerignore
# #3 transferring context: 2B done
# #3 DONE 0.0s
#
# #4 [1/3] FROM docker.io/amlight/kytos:latest@sha256:caff448da5b80807fc5856c00ff36ae76e4e04a875779e9f05dc401cb4bb160b
# #4 DONE 0.0s
#
# #5 [internal] load build context
# #5 transferring context: 626.05kB 0.0s done
# #5 DONE 0.0s
#
# #6 [2/3] COPY . /src/kytos-sdx
# #6 CACHED
#
# #7 [3/3] RUN python3 -m pip install --no-cache-dir -e /src/kytos-sdx
# #7 CACHED
#
# #8 exporting to image
# #8 exporting layers done
# #8 writing image sha256:9639815e55b2f14a04338c655e18f867757ba6dac95172241202cbb3a2fd7a1f done
# #8 naming to docker.io/library/kytos-sdx done
# #8 DONE 0.0s
# Done

# %% [markdown]
# ### Run end-to-end test

# %%
sdx_end_to_end_tests_repo = 'https://github.com/atlanticwave-sdx/sdx-end-to-end-tests.git'
sdx_end_to_end_tests_branch = 'main'
#sdx_end_to_end_tests_branch = "e2e_test_use_cases"
e2e_repo_dir = 'awsdx/sdx-end-to-end-tests'

# %% [markdown]
# ### 2. Checkout

# %%
commands5 = list()
commands5.append(f'[ ! -d ~/{e2e_repo_dir} ] && mkdir -p ~/{e2e_repo_dir}')
commands5.append(f'cd ~/{e2e_repo_dir} && git init && git remote add origin {sdx_end_to_end_tests_repo}')
commands5.append(f'cd ~/{e2e_repo_dir} && git fetch origin')
commands5.append(f'cd ~/{e2e_repo_dir} && git checkout {sdx_end_to_end_tests_branch}')

# Testing - customize for IPv6

# Add the following block to the docker-compose.yml
# Ref: https://docs.docker.com/reference/compose-file/networks/#the-default-network
#
#networks:
#   default:
#     name: sdxnet
#     enable_ipv6: true
#     ipam:
#       config:
#         - subnet: 2001:db8::/64

#management_ip = node.get_management_ip()

#if check_ip_version(management_ip) == 'IPv6':
#    commands1.append(f'cd ~/{repo_dir} && echo -e "networks:\n  default:\n    name: sdxnet\n    enable_ipv6: true\n    ipam:\n      config:\n        - subnet: 2001:db8::/64" | tee -a docker-compose.yml > /dev/null')


for command in commands5:
    print(f'Executing {command}')
    stdout, stderr = node.execute(command)
    
print('Done')

# %% [markdown]
# ### 3. Start Tests

# %%
# Testing - start 

commands6 = list()
commands6.append(f'sudo systemctl start docker')
commands6.append(f'cd ~/{e2e_repo_dir} && docker compose up -d &> /tmp/docker-compose.log')
commands6.append(f'cd ~/{e2e_repo_dir} && docker compose ps -a')

for command in commands6:
    print(f'Executing {command}')
    stdout, stderr = node.execute(command)
    
print('Done')
# Out:
# Executing sudo systemctl start docker
# Executing cd ~/awsdx/sdx-end-to-end-tests && docker compose up -d &> /tmp/docker-compose.log
# Executing cd ~/awsdx/sdx-end-to-end-tests && docker compose ps -a
# NAME                                    IMAGE                       COMMAND                  SERVICE          CREATED         STATUS                   PORTS
# sdx-end-to-end-tests-ampath-1           amlight/kytos-sdx:latest    "/bin/bash -x -c '# …"   ampath           9 seconds ago   Up 2 seconds             6653/tcp, 8181/tcp
# sdx-end-to-end-tests-ampath-lc-1        awsdx/sdx-lc:latest         "/bin/bash -x -c '# …"   ampath-lc        9 seconds ago   Up 1 second
# sdx-end-to-end-tests-mininet-1          italovalcy/mininet:latest   "/bin/bash -x -c 'se…"   mininet          9 seconds ago   Up 2 seconds             6633/tcp, 6640/tcp, 6653/tcp
# sdx-end-to-end-tests-mongo-1            mongo:7.0                   "docker-entrypoint.s…"   mongo            9 seconds ago   Up 8 seconds (healthy)   27017/tcp
# sdx-end-to-end-tests-mq1-1              rabbitmq:latest             "docker-entrypoint.s…"   mq1              9 seconds ago   Up 8 seconds (healthy)   4369/tcp, 5671-5672/tcp, 15691-15692/tcp, 25672/tcp
# sdx-end-to-end-tests-sax-1              amlight/kytos-sdx:latest    "/bin/bash -x -c '# …"   sax              9 seconds ago   Up 2 seconds             6653/tcp, 8181/tcp
# sdx-end-to-end-tests-sax-lc-1           awsdx/sdx-lc:latest         "/bin/bash -x -c '# …"   sax-lc           9 seconds ago   Up 1 second
# sdx-end-to-end-tests-sdx-controller-1   sdx-controller:latest       "/bin/bash -x -c '# …"   sdx-controller   9 seconds ago   Up 1 second              8080/tcp
# sdx-end-to-end-tests-tenet-1            amlight/kytos-sdx:latest    "/bin/bash -x -c '# …"   tenet            9 seconds ago   Up 2 seconds             6653/tcp, 8181/tcp
# sdx-end-to-end-tests-tenet-lc-1         awsdx/sdx-lc:latest         "/bin/bash -x -c '# …"   tenet-lc         9 seconds ago   Up 1 second
# Done

# %%
#docker exec -it sdx-end-to-end-tests-mongo-1  bash
#mongosh --username root_user --password root_pw
#show dbs
#use sdxctldb
#show collections
#show users
#db.links.find()

# %%
# Testing - execute

commands7 = list()
commands7.append(f'cd ~/{e2e_repo_dir} && ./wait-mininet-ready.sh')
#commands7.append(f'cd ~/{e2e_repo_dir} && docker compose exec -it mininet python3 -m pytest tests/test_20_use_case_topology.py::TestE2ETopologyUseCases::test_011_intra_domain_link_down_path_found | tee /tmp/docker-compose-exec-pytest.out')
#commands7.append(f'cd ~/{e2e_repo_dir} && docker compose exec -it mininet python3 -m pytest tests/test_20_use_case_topology.py | tee /tmp/docker-compose-exec-pytest.out')
commands7.append(f'cd ~/{e2e_repo_dir} && docker compose exec -it mininet python3 -m pytest | tee /tmp/docker-compose-exec-pytest.out')
commands7.append(f'cd ~/{e2e_repo_dir} && docker compose logs sdx-controller -t > /tmp/docker-compose-logs-sdx-controller.out')


for command in commands7:
    print(f'Executing {command}')
    stdout, stderr = node.execute(command)
    
print('Done')
# Out:
# Executing cd ~/awsdx/sdx-end-to-end-tests && ./wait-mininet-ready.sh
# Executing cd ~/awsdx/sdx-end-to-end-tests && docker compose exec -it mininet python3 -m pytest | tee /tmp/docker-compose-exec-pytest.out
# ============================= test session starts ==============================
# platform linux -- Python 3.11.2, pytest-7.2.1, pluggy-1.0.0+repack
# rootdir: /sdx-end-to-end-tests
# plugins: unordered-0.7.0
# collected 95 items
#
# tests/test_01_topology.py .....                                          [  5%]
# tests/test_05_l2vpn.py ........                                          [ 13%]
# tests/test_06_l2vpn_return_codes.py ..................................   [ 49%]
# tests/test_07_l2vpn_return_codes.py .......................              [ 73%]
# tests/test_08_l2vpn_return_codes.py ......                               [ 80%]
# tests/test_20_use_case_topology.py Xx.x.xx...x                          [ 92%]
# tests/test_21_use_case_topology.py x.xx                                  [ 96%]
# tests/test_99_topology_big_changes.py ...                                [100%]
#
# ------------------------------- start/stop times -------------------------------
# ============ 86 passed, 8 xfailed, 1 xpassed in 1653.31s (0:27:33) =============
# Executing cd ~/awsdx/sdx-end-to-end-tests && docker compose logs sdx-controller -t > /tmp/docker-compose-logs-sdx-controller.out
# Done

# %%
# !pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.14.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.14.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 26.1 MB/s eta 0:00:00a 0:00:01
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 43.1 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.14.0

# %%
import os
import time
from urllib.parse import urlparse

import pymongo
db_name = os.environ.get("DB_NAME") or "sdx-controllder-test-db"
mongo_user = os.getenv("MONGO_USER") or "guest"
mongo_pass = os.getenv("MONGO_PASS") or "guest"
mongo_host = os.getenv("MONGO_HOST") or "localhost"
mongo_port = os.getenv("MONGO_PORT") or 27017

mongo_connstring = (
                f"mongodb://{mongo_user}:{mongo_pass}@{mongo_host}:{mongo_port}/"
            )
mongo_client = pymongo.MongoClient(mongo_connstring)

# %% [markdown]
# ### 4. Stop (Optional)

# %%
commands = list()
commands.append(f'cd ~/{e2e_repo_dir} && docker compose down')


for command in commands:
    print(f'Executing {command}')
    stdout, stderr = node.execute(command)
    
print('Done')
# Out:
# Executing cd ~/awsdx/sdx-end-to-end-tests && docker compose down
#  Container sdx-end-to-end-tests-ampath-lc-1  Stopping
#  Container sdx-end-to-end-tests-tenet-lc-1  Stopping
#  Container sdx-end-to-end-tests-sax-lc-1  Stopping
#  Container sdx-end-to-end-tests-mininet-1  Stopping
#  Container sdx-end-to-end-tests-sdx-controller-1  Stopping
#  Container sdx-end-to-end-tests-sdx-controller-1  Stopped
#  Container sdx-end-to-end-tests-sdx-controller-1  Removing
#  Container sdx-end-to-end-tests-sdx-controller-1  Removed
#  Container sdx-end-to-end-tests-ampath-lc-1  Stopped
#  Container sdx-end-to-end-tests-ampath-lc-1  Removing
#  Container sdx-end-to-end-tests-ampath-lc-1  Removed
#  Container sdx-end-to-end-tests-mininet-1  Stopped
#  Container sdx-end-to-end-tests-mininet-1  Removing
#  Container sdx-end-to-end-tests-sax-lc-1  Stopped
#  Container sdx-end-to-end-tests-sax-lc-1  Removing
#  Container sdx-end-to-end-tests-sax-lc-1  Removed
#  Container sdx-end-to-end-tests-mininet-1  Removed
#  Container sdx-end-to-end-tests-tenet-1  Stopping
#  Container sdx-end-to-end-tests-ampath-1  Stopping
#  Container sdx-end-to-end-tests-sax-1  Stopping
#  Container sdx-end-to-end-tests-tenet-lc-1  Stopped
#  Container sdx-end-to-end-tests-tenet-lc-1  Removing
#  Container sdx-end-to-end-tests-tenet-lc-1  Removed
#  Container sdx-end-to-end-tests-mq1-1  Stopping
#  Container sdx-end-to-end-tests-mq1-1  Stopped
#  Container sdx-end-to-end-tests-mq1-1  Removing
#  Container sdx-end-to-end-tests-mq1-1  Removed
#  Container sdx-end-to-end-tests-sax-1  Stopped
#  Container sdx-end-to-end-tests-sax-1  Removing
#  Container sdx-end-to-end-tests-sax-1  Removed
#  Container sdx-end-to-end-tests-tenet-1  Stopped
#  Container sdx-end-to-end-tests-tenet-1  Removing
#  Container sdx-end-to-end-tests-tenet-1  Removed
#  Container sdx-end-to-end-tests-ampath-1  Stopped
#  Container sdx-end-to-end-tests-ampath-1  Removing
#  Container sdx-end-to-end-tests-ampath-1  Removed
#  Container sdx-end-to-end-tests-mongo-1  Stopping
#  Container sdx-end-to-end-tests-mongo-1  Stopped
#  Container sdx-end-to-end-tests-mongo-1  Removing
#  Container sdx-end-to-end-tests-mongo-1  Removed
#  Network sdx-end-to-end-tests_default  Removing
#  Network sdx-end-to-end-tests_default  Removed
# Done

# %% [markdown]
# ### 5. Prune system (Optional)

# %% [markdown]
# ##### 5.1 Prune docker

# %%
commands = list()
commands.append(f'cd ~/{e2e_repo_dir} && docker system prune -a --volumes')


for command in commands:
    print(f'Executing {command}')
    ###stdout, stderr = node.execute(command)
    
print('Done')
# Out:
# Executing cd ~/awsdx/sdx-end-to-end-tests && docker system prune -a --volumes
# Done

# %% [markdown]
# ##### 5.2 Prune directory

# %%
commands = list()
commands.append(f'rm -rf ~/{repo_dir}')


for command in commands:
    print(f'Executing {command}')
    ###stdout, stderr = node.execute(command)
    
print('Done')

# %% [markdown]
# ### 6. Execute Tests

# %% [markdown]
# ##### 6.1 Upload scripts

# %%
node = node1
local_directory_path = 'sdx-continuous-development'
remote_directory_path = '~/awsdx/'
script_dir = remote_directory_path + local_directory_path
node.upload_directory(local_directory_path=local_directory_path, remote_directory_path=remote_directory_path)
# Out:
# 'success'

# %%
stdout, stderr = node.execute(f'chmod +x {script_dir}/*')

# %% [markdown]
# ##### 6.2 Deploy system (This is the same action as Step-7 item 2,3) - Added here for completeness

# %%
###stdout, stderr = node.execute(f'{script_dir}/deploy-single-server.sh deploy {remote_directory_path}')

# %% [markdown]
# ##### 6.3 Stop the system - Added here for completeness

# %%
###stdout, stderr = node.execute(f'{script_dir}/deploy-single-server.sh stop {remote_directory_path}')

# %% [markdown]
# ##### 6.4 Start the system - Added here for completeness

# %%
###stdout, stderr = node.execute(f'{script_dir}/deploy-single-server.sh start {remote_directory_path}')

# %% [markdown]
# ##### 6.5 Query OXPs to make sure all of the expected switches are connected

# %%
stdout, stderr = node.execute(f'{script_dir}/deploy-single-server.sh wait_for_oxp_bootup {remote_directory_path}')
stdout, stderr = node.execute(f'{script_dir}/deploy-single-server.sh oxp_query_switches {remote_directory_path}')
# Out:
# bash: /home/rocky/awsdx/sdx-continuous-development/deploy-single-server.sh: No such file or directory
# bash: /home/rocky/awsdx/sdx-continuous-development/deploy-single-server.sh: No such file or directory

# %% [markdown]
# ##### 6.6 Enable the switches and links in OXPs

# %%
stdout, stderr = node.execute(f'{script_dir}/deploy-single-server.sh oxp_switch_enable {remote_directory_path}')

# %% [markdown]
# ##### 6.7 Query OXPs to make sure all of the expected switches are connected and their details

# %%
stdout, stderr = node.execute(f'{script_dir}/deploy-single-server.sh oxp_query_switches_detail {remote_directory_path}')

# %% [markdown]
# ##### 6.8 SDX Check topology

# %%
stdout, stderr = node.execute(f'{script_dir}/deploy-single-server.sh sdx_query_topology {remote_directory_path}')

# %% [markdown]
# ##### 6.9 SDX Check topology links

# %%
stdout, stderr = node.execute(f'{script_dir}/deploy-single-server.sh sdx_query_links {remote_directory_path}')

# %% [markdown]
# ##### 6.10 Mininet OVS status

# %%
stdout, stderr = node.execute(f'{script_dir}/deploy-single-server.sh mininet_ovs_vsctl_show {remote_directory_path}')

# %% [markdown]
# ##### 6.11 Check OXPs for services

# %%
stdout, stderr = node.execute(f'{script_dir}/deploy-single-server.sh oxp_query_mef_eline {remote_directory_path}')

# %% [markdown]
# ##### 6.12 Create L2VPN service

# %%
stdout, stderr = node.execute(f'{script_dir}/deploy-single-server.sh oxp_create_service_1 {remote_directory_path}')

# %% [markdown]
# ##### 6.13 Check OXPs for services

# %%
stdout, stderr = node.execute(f'{script_dir}/deploy-single-server.sh oxp_query_mef_eline {remote_directory_path}')

# %% [markdown]
# ##### 6.14 Create L2VPN service

# %%
stdout, stderr = node.execute(f'{script_dir}/deploy-single-server.sh oxp_create_service_2 {remote_directory_path}')

# %% [markdown]
# ##### 6.15 Check OXPs for services

# %%
stdout, stderr = node.execute(f'{script_dir}/deploy-single-server.sh oxp_query_mef_eline {remote_directory_path}')

# %% [markdown]
# ##### 6.16 Test Traffic

# %%
stdout, stderr = node.execute(f'{script_dir}/deploy-single-server.sh test_traffic {remote_directory_path}')

# %% [markdown]
# ### Docker Hub Login (optional)
# Create personal access token -> https://docs.docker.com/security/for-developers/access-tokens/

# %%
# Docker Login - when necessary

docker_access_token = '<DOCKER_PERSONAL_ACCESS_TOKEN>'
docker_user_account = '<DOCKER_USER_ACCOUNT>'

commands = list()
#commands.append(f'echo {docker_access_token} | docker login --username {docker_user_account} --password-stdin')

for command in commands:
    print(f'Executing {command}')
    stdout, stderr = node.execute(command)
    
print('Done')

# %% [markdown]
# ## Step 8: Delete the Slice
#
# Please delete your slice when you are done with your experiment.

# %%
try:
    slice = fablib.get_slice(name=slice_name)
    ###slice.delete()
except Exception as e:
    print(f"Exception: {e}")
